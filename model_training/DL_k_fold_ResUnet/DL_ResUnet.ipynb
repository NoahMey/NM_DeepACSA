# %%
import os
#import random
#import pandas as pd
import numpy as np
#import glob
#import matplotlib.pyplot as plt
#plt.style.use("ggplot")
#%matplotlib inline

from sklearn.model_selection import KFold, train_test_split
import cv2

from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from keras.optimizers import Adam


#unet collection
from keras_unet_collection import models
#import tensorflow as tf
from PIL import Image
from datetime import datetime

# %% [markdown]
# ## DL ResUnet with Keras Unet Collection

# %%
#define directory where images and masks are located
image_directory = 'D:/UniBas/Bachelorarbeit/Img_masks/DeepACSA_images_RF/insert_images/'
mask_directory = 'D:/UniBas/Bachelorarbeit/Img_masks/DeepACSA_masks_RF/insert_masks/'

#define the 
SIZE = 256
image_dataset = []
mask_dataset = []


#define custom function
def IoU(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
    iou = (intersection + smooth) / ( union + smooth)
    return iou

#enumerate and resize images/masks
images = os.listdir(image_directory)
for i, image_name in enumerate(images):    #enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'tif'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory+image_name, 1)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        image_dataset.append(np.array(image))


masks = os.listdir(mask_directory)
for i, image_name in enumerate(masks):
    if (image_name.split('.')[1] == 'tif'):
        image = cv2.imread(mask_directory+image_name, 0)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        mask_dataset.append(np.array(image))

num_labels = 1  #Binary classificaion 
batch_size = 2
epochs = 60


#Normalize images
image_dataset = np.array(image_dataset)/255.
#D not normalize masks, just rescale to 0 to 1.
mask_dataset = np.expand_dims((np.array(mask_dataset)),3) /255.

#define callback function
callbacks = [
  EarlyStopping(patience=8, verbose=1),
  ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, verbose=1),
  ModelCheckpoint('A_modelResunetV1.h5', verbose=1, save_best_only=True, save_weights_only=False), # Give the model a name (the .h5 part)
  CSVLogger('A_modelResunetV1.csv', separator=',', append=False)]

# Define the model architecture
# resunet requires depth >= 2
resunet = models.resunet_a_2d((256, 256, 3), [64, 128, 256, 512], 
                          dilation_num=[1, 3, 15, 31], 
                          n_labels=num_labels, aspp_num_down=256, aspp_num_up=128, 
                          activation='ReLU', output_activation='Softmax', 
                          batch_norm=True, pool="max", unpool='nearest', name='resunet')

# Compile the model
resunet.compile(loss='binary_crossentropy', optimizer=Adam(lr = 1e-3), 
            metrics=['accuracy', IoU])

#split dataset into training and validation set
X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size = 0.10, random_state = 0)

start2 = datetime.now() 

# Fit data to model
resunet_history = resunet.fit(X_train, y_train, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test), 
                    shuffle=False,
                    epochs=epochs,
                    callbacks=callbacks)

stop2 = datetime.now()
#Execution time of the model 
execution_time = stop2-start2
print("R2-Unet fitting time is: ", execution_time)
# Out:
# Received dilation rates: [1, 3, 15, 31]
# Received dilation rates are not defined on a per downsampling level basis.
# Automated determinations are applied with the following details:
# 	depth-0, dilation_rate = [1, 3, 15, 31]
# 	depth-1, dilation_rate = [1, 3, 15, 31]
# 	depth-2, dilation_rate = [1, 3, 15]
# 	depth-3, dilation_rate = [1]
# Epoch 1/60
# 230/230 [==============================] - 3145s 14s/step - loss: 13.9954 - accuracy: 0.0792 - IoU: 0.5411 - val_loss: 14.0875 - val_accuracy: 0.0734 - val_IoU: 0.5381
#
# Epoch 00001: val_loss improved from inf to 14.08753, saving model to A_modelResunetV1.h5
# Epoch 2/60
# 230/230 [==============================] - 3110s 14s/step - loss: 13.9954 - accuracy: 0.0792 - IoU: 0.5411 - val_loss: 14.0875 - val_accuracy: 0.0734 - val_IoU: 0.5381
#
# Epoch 00002: val_loss did not improve from 14.08753
# Epoch 3/60
# 230/230 [==============================] - 3115s 14s/step - loss: 13.9954 - accuracy: 0.0792 - IoU: 0.5411 - val_loss: 14.0875 - val_accuracy: 0.0734 - val_IoU: 0.5381
#
# Epoch 00003: val_loss did not improve from 14.08753
# Epoch 4/60
# 230/230 [==============================] - 3116s 14s/step - loss: 13.9954 - accuracy: 0.0792 - IoU: 0.5411 - val_loss: 14.0875 - val_accuracy: 0.0734 - val_IoU: 0.5381
#
# Epoch 00004: val_loss did not improve from 14.08753
# Epoch 5/60
# 230/230 [==============================] - 3125s 14s/step - loss: 13.9954 - accuracy: 0.0792 - IoU: 0.5411 - val_loss: 14.0875 - val_accuracy: 0.0734 - val_IoU: 0.5381
#
# Epoch 00005: val_loss did not improve from 14.08753
# Epoch 6/60
# 230/230 [==============================] - 3115s 14s/step - loss: 13.9954 - accuracy: 0.0792 - IoU: 0.5411 - val_loss: 14.0875 - val_accuracy: 0.0734 - val_IoU: 0.5381
#
# Epoch 00006: val_loss did not improve from 14.08753
# Epoch 7/60
# 230/230 [==============================] - 3119s 14s/step - loss: 13.9954 - accuracy: 0.0792 - IoU: 0.5411 - val_loss: 14.0875 - val_accuracy: 0.0734 - val_IoU: 0.5381
#
# Epoch 00007: val_loss did not improve from 14.08753
# Epoch 8/60
# 230/230 [==============================] - 3121s 14s/step - loss: 13.9954 - accuracy: 0.0792 - IoU: 0.5411 - val_loss: 14.0875 - val_accuracy: 0.0734 - val_IoU: 0.5381
#
# Epoch 00008: val_loss did not improve from 14.08753
# Epoch 9/60
# 230/230 [==============================] - 3119s 14s/step - loss: 13.9954 - accuracy: 0.0792 - IoU: 0.5411 - val_loss: 14.0875 - val_accuracy: 0.0734 - val_IoU: 0.5381
#
# Epoch 00009: val_loss did not improve from 14.08753
# Epoch 00009: early stopping
# R2-Unet fitting time is:  7:48:06.096107

# %%
#define directory where images and masks are located
image_directory = 'D:/UniBas/Bachelorarbeit/DeepACSA_images_VL/little_images/'
mask_directory = 'D:/UniBas/Bachelorarbeit/DeepACSA_masks_VL/little_masks/'

#define the 
SIZE = 256
image_dataset = []
mask_dataset = []


#define custom function
def IoU(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
    iou = (intersection + smooth) / ( union + smooth)
    return iou

#enumerate and resize images/masks
images = os.listdir(image_directory)
for i, image_name in enumerate(images):    #enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'tif'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory+image_name, 1)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        image_dataset.append(np.array(image))


masks = os.listdir(mask_directory)
for i, image_name in enumerate(masks):
    if (image_name.split('.')[1] == 'tif'):
        image = cv2.imread(mask_directory+image_name, 0)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        mask_dataset.append(np.array(image))

num_labels = 1  #Binary classificaion 
batch_size = 1
epochs = 6
num_folds = 5

#Normalize images
image_dataset = np.array(image_dataset)/255.
#D not normalize masks, just rescale to 0 to 1.
mask_dataset = np.expand_dims((np.array(mask_dataset)),3) /255.

# Define the K-fold Cross Validator
kfold = KFold(n_splits=num_folds, shuffle=False)

# Define per-fold score containers 
acc_per_fold = []
loss_per_fold = []
IoU_per_fold = []

# K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(image_dataset, mask_dataset):
  callbacks = [
    EarlyStopping(patience=8, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, verbose=1),
    ModelCheckpoint(f'K-foldno{fold_no}-resunet-VL-256.h5', verbose=1, save_best_only=True, save_weights_only=False), # Give the model a name (the .h5 part)
    CSVLogger(f'K-foldno{fold_no}-resunet-VL-256.csv', separator=',', append=False)]

  # Define the model architecture
  # resunet requires depth >= 2
  resunet = models.resunet_a_2d((256, 256, 3), [64, 128, 256, 512], 
                            dilation_num=[1, 3, 15, 31], 
                            n_labels=2, aspp_num_down=256, aspp_num_up=128, 
                            activation='ReLU', output_activation='Softmax', 
                            batch_norm=True, pool="max", unpool='nearest', name='resunet')

  # Compile the model
  resunet.compile(loss='binary_crossentropy', optimizer=Adam(lr = 1e-3), 
              metrics=['accuracy', IoU])

  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')

  # Fit data to model
  resunet_history = resunet.fit(image_dataset[train], mask_dataset[train], 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(image_dataset[test], mask_dataset[test]), 
                    shuffle=False,
                    epochs=epochs,
                    callbacks=callbacks)

  #append evaluation values for every fold to a list
  acc_per_fold.append(resunet.evaluate(image_dataset[test], mask_dataset[test])[1])
  loss_per_fold.append(resunet.evaluate(image_dataset[test], mask_dataset[test])[0])
  IoU_per_fold.append(resunet.evaluate(image_dataset[test], mask_dataset[test])[2])

  # Increase fold number
  fold_no += 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]} - IoU: {IoU_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print(f'> IoU: {np.mean(IoU_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# Received dilation rates: [1, 3, 15, 31]
# Received dilation rates are not defined on a per downsampling level basis.
# Automated determinations are applied with the following details:
# 	depth-0, dilation_rate = [1, 3, 15, 31]
# 	depth-1, dilation_rate = [1, 3, 15, 31]
# 	depth-2, dilation_rate = [1, 3, 15]
# 	depth-3, dilation_rate = [1]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/6
# 25/25 [==============================] - 190s 7s/step - loss: 0.7862 - accuracy: 0.4971 - IoU: 0.5461 - val_loss: 3.9473 - val_accuracy: 0.9037 - val_IoU: 0.5458
#
# Epoch 00001: val_loss improved from inf to 3.94728, saving model to K-foldno1-resunet-VL-256.h5
# Epoch 2/6
# 25/25 [==============================] - 183s 7s/step - loss: 0.6964 - accuracy: 0.5014 - IoU: 0.5461 - val_loss: 0.6938 - val_accuracy: 0.4271 - val_IoU: 0.5458
#
# Epoch 00002: val_loss improved from 3.94728 to 0.69385, saving model to K-foldno1-resunet-VL-256.h5
# Epoch 3/6
# 25/25 [==============================] - 184s 7s/step - loss: 0.6950 - accuracy: 0.4746 - IoU: 0.5461 - val_loss: 0.6937 - val_accuracy: 0.4703 - val_IoU: 0.5458
#
# Epoch 00003: val_loss improved from 0.69385 to 0.69366, saving model to K-foldno1-resunet-VL-256.h5
# Epoch 4/6
# 25/25 [==============================] - 184s 7s/step - loss: 0.6941 - accuracy: 0.4974 - IoU: 0.5461 - val_loss: 0.6936 - val_accuracy: 0.4979 - val_IoU: 0.5458
#
# Epoch 00004: val_loss improved from 0.69366 to 0.69357, saving model to K-foldno1-resunet-VL-256.h5
# Epoch 5/6
# 25/25 [==============================] - 183s 7s/step - loss: 0.6941 - accuracy: 0.5101 - IoU: 0.5461 - val_loss: 0.6935 - val_accuracy: 0.4805 - val_IoU: 0.5458
#
# Epoch 00005: val_loss improved from 0.69357 to 0.69350, saving model to K-foldno1-resunet-VL-256.h5
# Epoch 6/6
# 25/25 [==============================] - 184s 7s/step - loss: 0.6942 - accuracy: 0.4938 - IoU: 0.5461 - val_loss: 0.6935 - val_accuracy: 0.4605 - val_IoU: 0.5458
#
# Epoch 00006: val_loss improved from 0.69350 to 0.69347, saving model to K-foldno1-resunet-VL-256.h5
# 1/1 [==============================] - 12s 12s/step - loss: 0.6935 - accuracy: 0.4605 - IoU: 0.5458
# 1/1 [==============================] - 11s 11s/step - loss: 0.6935 - accuracy: 0.4605 - IoU: 0.5458
# 1/1 [==============================] - 10s 10s/step - loss: 0.6935 - accuracy: 0.4605 - IoU: 0.5458
# Received dilation rates: [1, 3, 15, 31]
# Received dilation rates are not defined on a per downsampling level basis.
# Automated determinations are applied with the following details:
# 	depth-0, dilation_rate = [1, 3, 15, 31]
# 	depth-1, dilation_rate = [1, 3, 15, 31]
# 	depth-2, dilation_rate = [1, 3, 15]
# 	depth-3, dilation_rate = [1]
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/6
# 25/25 [==============================] - 190s 7s/step - loss: 0.7885 - accuracy: 0.4992 - IoU: 0.5472 - val_loss: 1.2717 - val_accuracy: 0.0870 - val_IoU: 0.5459
#
# Epoch 00001: val_loss improved from inf to 1.27173, saving model to K-foldno2-resunet-VL-256.h5
# Epoch 2/6
# 25/25 [==============================] - 181s 7s/step - loss: 0.6969 - accuracy: 0.4741 - IoU: 0.5472 - val_loss: 0.7059 - val_accuracy: 0.0870 - val_IoU: 0.5459
#
# Epoch 00002: val_loss improved from 1.27173 to 0.70590, saving model to K-foldno2-resunet-VL-256.h5
# Epoch 3/6
# 25/25 [==============================] - 179s 7s/step - loss: 0.6957 - accuracy: 0.4783 - IoU: 0.5472 - val_loss: 0.7143 - val_accuracy: 0.0870 - val_IoU: 0.5459
#
# Epoch 00003: val_loss did not improve from 0.70590
# Epoch 4/6
# 25/25 [==============================] - 181s 7s/step - loss: 0.6946 - accuracy: 0.5061 - IoU: 0.5472 - val_loss: 0.7223 - val_accuracy: 0.0870 - val_IoU: 0.5459
#
# Epoch 00004: val_loss did not improve from 0.70590
# Epoch 5/6
# 25/25 [==============================] - 180s 7s/step - loss: 0.6942 - accuracy: 0.4897 - IoU: 0.5472 - val_loss: 0.7349 - val_accuracy: 0.0870 - val_IoU: 0.5459
#
# Epoch 00005: val_loss did not improve from 0.70590
# Epoch 6/6
# 25/25 [==============================] - 183s 7s/step - loss: 0.6938 - accuracy: 0.5046 - IoU: 0.5472 - val_loss: 0.7548 - val_accuracy: 0.0870 - val_IoU: 0.5459
#
# Epoch 00006: val_loss did not improve from 0.70590
# 1/1 [==============================] - 11s 11s/step - loss: 0.7548 - accuracy: 0.0870 - IoU: 0.5459
# 1/1 [==============================] - 10s 10s/step - loss: 0.7548 - accuracy: 0.0870 - IoU: 0.5459
# 1/1 [==============================] - 10s 10s/step - loss: 0.7548 - accuracy: 0.0870 - IoU: 0.5459
# Received dilation rates: [1, 3, 15, 31]
# Received dilation rates are not defined on a per downsampling level basis.
# Automated determinations are applied with the following details:
# 	depth-0, dilation_rate = [1, 3, 15, 31]
# 	depth-1, dilation_rate = [1, 3, 15, 31]
# 	depth-2, dilation_rate = [1, 3, 15]
# 	depth-3, dilation_rate = [1]
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/6
# 26/26 [==============================] - 203s 8s/step - loss: 0.7790 - accuracy: 0.4919 - IoU: 0.5473 - val_loss: 1.0555 - val_accuracy: 0.4951 - val_IoU: 0.5446
#
# Epoch 00001: val_loss improved from inf to 1.05546, saving model to K-foldno3-resunet-VL-256.h5
# Epoch 2/6
# 26/26 [==============================] - 192s 7s/step - loss: 0.6968 - accuracy: 0.5250 - IoU: 0.5473 - val_loss: 0.6990 - val_accuracy: 0.9066 - val_IoU: 0.5446
#
# Epoch 00002: val_loss improved from 1.05546 to 0.69900, saving model to K-foldno3-resunet-VL-256.h5
# Epoch 3/6
# 26/26 [==============================] - 188s 7s/step - loss: 0.6953 - accuracy: 0.4848 - IoU: 0.5473 - val_loss: 0.7093 - val_accuracy: 0.9066 - val_IoU: 0.5446
#
# Epoch 00003: val_loss did not improve from 0.69900
# Epoch 4/6
# 26/26 [==============================] - 192s 7s/step - loss: 0.6940 - accuracy: 0.5101 - IoU: 0.5473 - val_loss: 0.7145 - val_accuracy: 0.9066 - val_IoU: 0.5446
#
# Epoch 00004: val_loss did not improve from 0.69900
# Epoch 5/6
# 26/26 [==============================] - 190s 7s/step - loss: 0.6938 - accuracy: 0.4982 - IoU: 0.5473 - val_loss: 0.7184 - val_accuracy: 0.9066 - val_IoU: 0.5446
#
# Epoch 00005: val_loss did not improve from 0.69900
# Epoch 6/6
# 26/26 [==============================] - 190s 7s/step - loss: 0.6936 - accuracy: 0.4996 - IoU: 0.5473 - val_loss: 0.7215 - val_accuracy: 0.9066 - val_IoU: 0.5446
#
# Epoch 00006: val_loss did not improve from 0.69900
# 1/1 [==============================] - 11s 11s/step - loss: 0.7215 - accuracy: 0.9066 - IoU: 0.5446
# 1/1 [==============================] - 10s 10s/step - loss: 0.7215 - accuracy: 0.9066 - IoU: 0.5446
# 1/1 [==============================] - 10s 10s/step - loss: 0.7215 - accuracy: 0.9066 - IoU: 0.5446
# Received dilation rates: [1, 3, 15, 31]
# Received dilation rates are not defined on a per downsampling level basis.
# Automated determinations are applied with the following details:
# 	depth-0, dilation_rate = [1, 3, 15, 31]
# 	depth-1, dilation_rate = [1, 3, 15, 31]
# 	depth-2, dilation_rate = [1, 3, 15]
# 	depth-3, dilation_rate = [1]
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/6
# 26/26 [==============================] - 204s 8s/step - loss: 0.7807 - accuracy: 0.5127 - IoU: 0.5468 - val_loss: 0.9019 - val_accuracy: 0.1137 - val_IoU: 0.5501
#
# Epoch 00001: val_loss improved from inf to 0.90187, saving model to K-foldno4-resunet-VL-256.h5
# Epoch 2/6
# 26/26 [==============================] - 207s 8s/step - loss: 0.6990 - accuracy: 0.4638 - IoU: 0.5468 - val_loss: 0.7022 - val_accuracy: 0.8568 - val_IoU: 0.5501
#
# Epoch 00002: val_loss improved from 0.90187 to 0.70217, saving model to K-foldno4-resunet-VL-256.h5
# Epoch 3/6
# 26/26 [==============================] - 202s 8s/step - loss: 0.6953 - accuracy: 0.4867 - IoU: 0.5468 - val_loss: 0.7003 - val_accuracy: 0.8230 - val_IoU: 0.5501
#
# Epoch 00003: val_loss improved from 0.70217 to 0.70033, saving model to K-foldno4-resunet-VL-256.h5
# Epoch 4/6
# 26/26 [==============================] - 198s 8s/step - loss: 0.6947 - accuracy: 0.4948 - IoU: 0.5468 - val_loss: 0.6951 - val_accuracy: 0.7938 - val_IoU: 0.5501
#
# Epoch 00004: val_loss improved from 0.70033 to 0.69514, saving model to K-foldno4-resunet-VL-256.h5
# Epoch 5/6
# 26/26 [==============================] - 198s 8s/step - loss: 0.6942 - accuracy: 0.5033 - IoU: 0.5468 - val_loss: 0.6940 - val_accuracy: 0.3378 - val_IoU: 0.5501
#
# Epoch 00005: val_loss improved from 0.69514 to 0.69398, saving model to K-foldno4-resunet-VL-256.h5
# Epoch 6/6
# 26/26 [==============================] - 199s 8s/step - loss: 0.6937 - accuracy: 0.4953 - IoU: 0.5468 - val_loss: 0.6978 - val_accuracy: 0.0960 - val_IoU: 0.5501
#
# Epoch 00006: val_loss did not improve from 0.69398
# 1/1 [==============================] - 12s 12s/step - loss: 0.6978 - accuracy: 0.0960 - IoU: 0.5501
# 1/1 [==============================] - 11s 11s/step - loss: 0.6978 - accuracy: 0.0960 - IoU: 0.5501
# 1/1 [==============================] - 11s 11s/step - loss: 0.6978 - accuracy: 0.0960 - IoU: 0.5501
# Received dilation rates: [1, 3, 15, 31]
# Received dilation rates are not defined on a per downsampling level basis.
# Automated determinations are applied with the following details:
# 	depth-0, dilation_rate = [1, 3, 15, 31]
# 	depth-1, dilation_rate = [1, 3, 15, 31]
# 	depth-2, dilation_rate = [1, 3, 15]
# 	depth-3, dilation_rate = [1]
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/6
# 26/26 [==============================] - 202s 8s/step - loss: 0.7752 - accuracy: 0.4817 - IoU: 0.5473 - val_loss: 6.2337 - val_accuracy: 0.0702 - val_IoU: 0.5372
#
# Epoch 00001: val_loss improved from inf to 6.23372, saving model to K-foldno5-resunet-VL-256.h5
# Epoch 2/6
# 26/26 [==============================] - 197s 8s/step - loss: 0.6968 - accuracy: 0.5099 - IoU: 0.5473 - val_loss: 0.6989 - val_accuracy: 0.0705 - val_IoU: 0.5372
#
# Epoch 00002: val_loss improved from 6.23372 to 0.69885, saving model to K-foldno5-resunet-VL-256.h5
# Epoch 3/6
# 26/26 [==============================] - 199s 8s/step - loss: 0.6956 - accuracy: 0.4890 - IoU: 0.5473 - val_loss: 0.7113 - val_accuracy: 0.0702 - val_IoU: 0.5372
#
# Epoch 00003: val_loss did not improve from 0.69885
# Epoch 4/6
# 26/26 [==============================] - 200s 8s/step - loss: 0.6946 - accuracy: 0.5017 - IoU: 0.5473 - val_loss: 0.7228 - val_accuracy: 0.0702 - val_IoU: 0.5372
#
# Epoch 00004: val_loss did not improve from 0.69885
# Epoch 5/6
# 26/26 [==============================] - 196s 8s/step - loss: 0.6945 - accuracy: 0.5013 - IoU: 0.5473 - val_loss: 0.7350 - val_accuracy: 0.0702 - val_IoU: 0.5372
#
# Epoch 00005: val_loss did not improve from 0.69885
# Epoch 6/6
# 26/26 [==============================] - 194s 7s/step - loss: 0.6943 - accuracy: 0.4872 - IoU: 0.5473 - val_loss: 0.7497 - val_accuracy: 0.0702 - val_IoU: 0.5372
#
# Epoch 00006: val_loss did not improve from 0.69885
# 1/1 [==============================] - 10s 10s/step - loss: 0.7497 - accuracy: 0.0702 - IoU: 0.5372
# 1/1 [==============================] - 9s 9s/step - loss: 0.7497 - accuracy: 0.0702 - IoU: 0.5372
# 1/1 [==============================] - 9s 9s/step - loss: 0.7497 - accuracy: 0.0702 - IoU: 0.5372
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6934710741043091 - Accuracy: 0.4604732096195221%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.7547838091850281 - Accuracy: 0.0870448499917984%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.7214741706848145 - Accuracy: 0.9065602421760559%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6978304386138916 - Accuracy: 0.0959828719496727%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.7496683597564697 - Accuracy: 0.0701853409409523%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 0.3240493029356003 (+- 0.32574922732285055)
# > Loss: 0.7234455704689026
# ------------------------------------------------------------------------
