# %%
import os
#import random
#import pandas as pd
import numpy as np
#import glob
#import matplotlib.pyplot as plt
#plt.style.use("ggplot")
#%matplotlib inline

from sklearn.model_selection import KFold, train_test_split
import cv2

from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model

from keras_unet_collection import models #Keras unet collection
#import tensorflow as tf
from PIL import Image
from datetime import datetime

# %% [markdown]
# ## DL Trans Unet without k-fold

# %%
#define directory where images and masks are located on local disk
image_directory = 'D:/UniBas/Bachelorarbeit/Img_masks/DeepACSA_images_RF/insert_images/'
mask_directory = 'D:/UniBas/Bachelorarbeit/Img_masks/DeepACSA_masks_RF/insert_masks/'


#define the properties and empty list for resized images and masks
SIZE = 256
image_dataset = []
mask_dataset = []


#define custom function
def IoU(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
    iou = (intersection + smooth) / ( union + smooth)
    return iou

#enumerate and resize images/masks
images = os.listdir(image_directory)
for i, image_name in enumerate(images):    #enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'tif'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory+image_name, 1)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        image_dataset.append(np.array(image))


masks = os.listdir(mask_directory)
for i, image_name in enumerate(masks):
    if (image_name.split('.')[1] == 'tif'):
        image = cv2.imread(mask_directory+image_name, 0)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        mask_dataset.append(np.array(image))

#define some hyperparameters
num_labels = 1  #Binary classificaion (missmatch with literature/code examples!)
batch_size = 2  #keep it smaller than 3
epochs = 60

#normalize images
image_dataset = np.array(image_dataset)/255.
#do not normalize masks, just rescale to 0 to 1.
mask_dataset = np.expand_dims((np.array(mask_dataset)),3) /255.

#define callback function
callbacks = [
  EarlyStopping(patience=8, verbose=1),
  ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, verbose=1),
  ModelCheckpoint('A_modelTransV1.h5', verbose=1, save_best_only=True, save_weights_only=False), # Give the model a name (the .h5 part)
  CSVLogger('A_modelTransV1.csv', separator=',', append=False)]

#define the model architecture
#model requires depth >= 2
model = models.transunet_2d((256, 256, 3), filter_num=[64, 128, 256, 512, 1024], 
                          n_labels=num_labels, stack_num_down=2, stack_num_up=2, 
                          embed_dim=768, num_mlp=3072, num_heads=12, num_transformer=12, 
                          activation='ReLU', mlp_activation='GELU', output_activation='Sigmoid', #output activation from Softmax to Sigmoid
                          batch_norm=True, pool=True, unpool='bilinear', name='transunet')
                          #batchnorm to true, unpool to false
#compile the model
model.compile(loss='binary_crossentropy', optimizer=Adam(lr = 1e-3), 
            metrics=['accuracy', IoU])

#split dataset into training and validation set
X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size = 0.10, random_state = 0)

#start time meauserment
start2 = datetime.now() 

# Fit data to model
resunet_history = model.fit(X_train, y_train, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test), 
                    shuffle=False,
                    epochs=epochs,
                    callbacks=callbacks)

#stop time measurement and print the execution time
stop2 = datetime.now() 
execution_time = stop2-start2
print("R2-Unet fitting time is: ", execution_time)
# Out:
# Epoch 1/60
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\VSCode\SACHEN\model_training\DL_k_fold_Trans_unet\DL_Trans_unet.ipynb Cell 3 in 7
#      <a href='vscode-notebook-cell:/d%3A/VSCode/SACHEN/model_training/DL_k_fold_Trans_unet/DL_Trans_unet.ipynb#W2sZmlsZQ%3D%3D?line=68'>69</a> start2 = datetime.now()
#      <a href='vscode-notebook-cell:/d%3A/VSCode/SACHEN/model_training/DL_k_fold_Trans_unet/DL_Trans_unet.ipynb#W2sZmlsZQ%3D%3D?line=70'>71</a> # Fit data to model
# ---> <a href='vscode-notebook-cell:/d%3A/VSCode/SACHEN/model_training/DL_k_fold_Trans_unet/DL_Trans_unet.ipynb#W2sZmlsZQ%3D%3D?line=71'>72</a> resunet_history = model.fit(X_train, y_train,
#      <a href='vscode-notebook-cell:/d%3A/VSCode/SACHEN/model_training/DL_k_fold_Trans_unet/DL_Trans_unet.ipynb#W2sZmlsZQ%3D%3D?line=72'>73</a>                     verbose=1,
#      <a href='vscode-notebook-cell:/d%3A/VSCode/SACHEN/model_training/DL_k_fold_Trans_unet/DL_Trans_unet.ipynb#W2sZmlsZQ%3D%3D?line=73'>74</a>                     batch_size = batch_size,
#      <a href='vscode-notebook-cell:/d%3A/VSCode/SACHEN/model_training/DL_k_fold_Trans_unet/DL_Trans_unet.ipynb#W2sZmlsZQ%3D%3D?line=74'>75</a>                     validation_data=(X_test, y_test),
#      <a href='vscode-notebook-cell:/d%3A/VSCode/SACHEN/model_training/DL_k_fold_Trans_unet/DL_Trans_unet.ipynb#W2sZmlsZQ%3D%3D?line=75'>76</a>                     shuffle=False,
#      <a href='vscode-notebook-cell:/d%3A/VSCode/SACHEN/model_training/DL_k_fold_Trans_unet/DL_Trans_unet.ipynb#W2sZmlsZQ%3D%3D?line=76'>77</a>                     epochs=epochs,
#      <a href='vscode-notebook-cell:/d%3A/VSCode/SACHEN/model_training/DL_k_fold_Trans_unet/DL_Trans_unet.ipynb#W2sZmlsZQ%3D%3D?line=77'>78</a>                     callbacks=callbacks)
#      <a href='vscode-notebook-cell:/d%3A/VSCode/SACHEN/model_training/DL_k_fold_Trans_unet/DL_Trans_unet.ipynb#W2sZmlsZQ%3D%3D?line=79'>80</a> stop2 = datetime.now()
#      <a href='vscode-notebook-cell:/d%3A/VSCode/SACHEN/model_training/DL_k_fold_Trans_unet/DL_Trans_unet.ipynb#W2sZmlsZQ%3D%3D?line=80'>81</a> #Execution time of the model
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\keras\engine\training.py:1100, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1093 with trace.Trace(
#    1094     'train',
#    1095     epoch_num=epoch,
#    1096     step_num=step,
#    1097     batch_size=batch_size,
#    1098     _r=1):
#    1099   callbacks.on_train_batch_begin(step)
# -> 1100   tmp_logs = self.train_function(iterator)
#    1101   if data_handler.should_sync:
#    1102     context.async_wait()
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\eager\def_function.py:828, in Function.__call__(self, *args, **kwds)
#     826 tracing_count = self.experimental_get_tracing_count()
#     827 with trace.Trace(self._name) as tm:
# --> 828   result = self._call(*args, **kwds)
#     829   compiler = "xla" if self._experimental_compile else "nonXla"
#     830   new_tracing_count = self.experimental_get_tracing_count()
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\eager\def_function.py:888, in Function._call(self, *args, **kwds)
#     884     pass  # Fall through to cond-based initialization.
#     885   else:
#     886     # Lifting succeeded, so variables are initialized and we can run the
#     887     # stateless function.
# --> 888     return self._stateless_fn(*args, **kwds)
#     889 else:
#     890   _, _, _, filtered_flat_args = \
#     891       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     892           *args, **kwds)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\eager\function.py:2941, in Function.__call__(self, *args, **kwargs)
#    2938 """Calls a graph function specialized to the inputs."""
#    2939 with self._lock:
#    2940   (graph_function,
# -> 2941    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942 return graph_function._call_flat(
#    2943     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\eager\function.py:3361, in Function._maybe_define_function(self, args, kwargs)
#    3357   return self._define_function_with_shape_relaxation(
#    3358       args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3360 self._function_cache.missed.add(call_context_key)
# -> 3361 graph_function = self._create_graph_function(args, kwargs)
#    3362 self._function_cache.primary[cache_key] = graph_function
#    3364 return graph_function, filtered_flat_args
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\eager\function.py:3196, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3191 missing_arg_names = [
#    3192     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3193 ]
#    3194 arg_names = base_arg_names + missing_arg_names
#    3195 graph_function = ConcreteFunction(
# -> 3196     func_graph_module.func_graph_from_py_func(
#    3197         self._name,
#    3198         self._python_function,
#    3199         args,
#    3200         kwargs,
#    3201         self.input_signature,
#    3202         autograph=self._autograph,
#    3203         autograph_options=self._autograph_options,
#    3204         arg_names=arg_names,
#    3205         override_flat_arg_shapes=override_flat_arg_shapes,
#    3206         capture_by_value=self._capture_by_value),
#    3207     self._function_attributes,
#    3208     function_spec=self.function_spec,
#    3209     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3210     # scope. This is not the default behavior since it gets used in some
#    3211     # places (like Keras) where the FuncGraph lives longer than the
#    3212     # ConcreteFunction.
#    3213     shared_func_graph=False)
#    3214 return graph_function
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\framework\func_graph.py:990, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     987 else:
#     988   _, original_func = tf_decorator.unwrap(python_func)
# --> 990 func_outputs = python_func(*func_args, **func_kwargs)
#     992 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#     993 # TensorArrays and `None`s.
#     994 func_outputs = nest.map_structure(convert, func_outputs,
#     995                                   expand_composites=True)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\eager\def_function.py:634, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     632     xla_context.Exit()
#     633 else:
# --> 634   out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635 return out
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\framework\func_graph.py:966, in func_graph_from_py_func.<locals>.wrapper(*args, **kwargs)
#     964 # TODO(mdan): Push this block higher in tf.function's call stack.
#     965 try:
# --> 966   return autograph.converted_call(
#     967       original_func,
#     968       args,
#     969       kwargs,
#     970       options=autograph.ConversionOptions(
#     971           recursive=True,
#     972           optional_features=autograph_options,
#     973           user_requested=True,
#     974       ))
#     975 except Exception as e:  # pylint:disable=broad-except
#     976   if hasattr(e, "ag_error_metadata"):
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     457 try:
#     458   if kwargs is not None:
# --> 459     result = converted_f(*effective_args, **kwargs)
#     460   else:
#     461     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\tmpoq9lgs80.py:16, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      14 try:
#      15     do_return = True
# ---> 16     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      17 except:
#      18     do_return = False
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\autograph\impl\api.py:350, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     348 if conversion.is_in_allowlist_cache(f, options):
#     349   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 350   return _call_unconverted(f, args, kwargs, options, False)
#     352 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     353   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\autograph\impl\api.py:479, in _call_unconverted(f, args, kwargs, options, update_cache)
#     477 if kwargs is not None:
#     478   return f(*args, **kwargs)
# --> 479 return f(*args)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\keras\engine\training.py:795, in Model.make_train_function.<locals>.step_function(model, iterator)
#     792   return outputs
#     794 data = next(iterator)
# --> 795 outputs = model.distribute_strategy.run(run_step, args=(data,))
#     796 outputs = reduce_per_replica(
#     797     outputs, self.distribute_strategy, reduction='first')
#     798 write_scalar_summaries(outputs, step=model._train_counter)  # pylint: disable=protected-access
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259, in StrategyBase.run(***failed resolving arguments***)
#    1254 with self.scope():
#    1255   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1256   # applied when when the caller is also in Eager mode.
#    1257   fn = autograph.tf_convert(
#    1258       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1259   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2728   kwargs = {}
#    2729 with self._container_strategy().scope():
# -> 2730   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3415 def _call_for_each_replica(self, fn, args, kwargs):
#    3416   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3417     return fn(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\autograph\impl\api.py:667, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     665 try:
#     666   with conversion_ctx:
# --> 667     return converted_call(f, args, kwargs, options=options)
#     668 except Exception as e:  # pylint:disable=broad-except
#     669   if hasattr(e, 'ag_error_metadata'):
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\autograph\impl\api.py:396, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     393   return _call_unconverted(f, args, kwargs, options)
#     395 if not options.user_requested and conversion.is_allowlisted(f):
# --> 396   return _call_unconverted(f, args, kwargs, options)
#     398 # internal_convert_user_code is for example turned off when issuing a dynamic
#     399 # call conversion from generated code while in nonrecursive mode. In that
#     400 # case we evidently don't want to recurse, but we still have to convert
#     401 # things like builtins.
#     402 if not options.internal_convert_user_code:
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\autograph\impl\api.py:478, in _call_unconverted(f, args, kwargs, options, update_cache)
#     475   return f.__self__.call(args, kwargs)
#     477 if kwargs is not None:
# --> 478   return f(*args, **kwargs)
#     479 return f(*args)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\keras\engine\training.py:788, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#     787 def run_step(data):
# --> 788   outputs = model.train_step(data)
#     789   # Ensure counter is updated only if `train_step` succeeds.
#     790   with ops.control_dependencies(_minimum_control_deps(outputs)):
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\keras\engine\training.py:754, in Model.train_step(self, data)
#     751 x, y, sample_weight = data_adapter.unpack_x_y_sample_weight(data)
#     753 with backprop.GradientTape() as tape:
# --> 754   y_pred = self(x, training=True)
#     755   loss = self.compiled_loss(
#     756       y, y_pred, sample_weight, regularization_losses=self.losses)
#     757 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:1012, in Layer.__call__(self, *args, **kwargs)
#    1008   self._maybe_build(inputs)
#    1010 with autocast_variable.enable_auto_cast_variables(
#    1011     self._compute_dtype_object):
# -> 1012   outputs = call_fn(inputs, *args, **kwargs)
#    1014 if self._activity_regularizer:
#    1015   self._handle_activity_regularization(inputs, outputs)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\keras\engine\functional.py:424, in Functional.call(self, inputs, training, mask)
#     406 def call(self, inputs, training=None, mask=None):
#     407   """Calls the model on new inputs.
#     408
#     409   In this case `call` just reapplies
#    (...)
#     422       a list of tensors if there are more than one outputs.
#     423   """
# --> 424   return self._run_internal_graph(
#     425       inputs, training=training, mask=mask)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\keras\engine\functional.py:560, in Functional._run_internal_graph(self, inputs, training, mask)
#     557   continue  # Node is not computable, try skipping.
#     559 args, kwargs = node.map_arguments(tensor_dict)
# --> 560 outputs = node.layer(*args, **kwargs)
#     562 # Update tensor_dict.
#     563 for x_id, y in zip(node.flat_output_ids, nest.flatten(outputs)):
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:1012, in Layer.__call__(self, *args, **kwargs)
#    1008   self._maybe_build(inputs)
#    1010 with autocast_variable.enable_auto_cast_variables(
#    1011     self._compute_dtype_object):
# -> 1012   outputs = call_fn(inputs, *args, **kwargs)
#    1014 if self._activity_regularizer:
#    1015   self._handle_activity_regularization(inputs, outputs)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\keras\layers\normalization.py:1305, in LayerNormalization.call(self, inputs)
#    1302 scale, offset = _broadcast(self.gamma), _broadcast(self.beta)
#    1304 if scale is not None:
# -> 1305   outputs = outputs * math_ops.cast(scale, outputs.dtype)
#    1306 if offset is not None:
#    1307   outputs = outputs + math_ops.cast(offset, outputs.dtype)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\ops\math_ops.py:1164, in _OverrideBinaryOperatorHelper.<locals>.binary_op_wrapper(x, y)
#    1162 with ops.name_scope(None, op_name, [x, y]) as name:
#    1163   try:
# -> 1164     return func(x, y, name=name)
#    1165   except (TypeError, ValueError) as e:
#    1166     # Even if dispatching the op failed, the RHS may be a tensor aware
#    1167     # object that can implement the operator with knowledge of itself
#    (...)
#    1170     # original error from the LHS, because it may be more
#    1171     # informative.
#    1172     if hasattr(type(y), "__r%s__" % op_name):
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\ops\math_ops.py:1496, in _mul_dispatch(x, y, name)
#    1494   return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1495 else:
# -> 1496   return multiply(x, y, name=name)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\util\dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#     200 try:
# --> 201   return target(*args, **kwargs)
#     202 except (TypeError, ValueError):
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#     205   result = dispatch(wrapper, args, kwargs)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\ops\math_ops.py:518, in multiply(x, y, name)
#     472 @tf_export("math.multiply", "multiply")
#     473 @dispatch.add_dispatch_support
#     474 def multiply(x, y, name=None):
#     475   """Returns an element-wise x * y.
#     476
#     477   For example:
#    (...)
#     515    * InvalidArgumentError: When `x` and `y` have incomptatible shapes or types.
#     516   """
# --> 518   return gen_math_ops.mul(x, y, name)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:6076, in mul(x, y, name)
#    6074     pass  # Add nodes to the TensorFlow graph.
#    6075 # Add nodes to the TensorFlow graph.
# -> 6076 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    6077       "Mul", x=x, y=y, name=name)
#    6078 _result = _outputs[:]
#    6079 if _execute.must_record_gradient():
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\framework\op_def_library.py:517, in _apply_op_helper(op_type_name, name, **keywords)
#     511       values = ops.convert_to_tensor(
#     512           values,
#     513           name=input_arg.name,
#     514           as_ref=input_arg.is_ref,
#     515           preferred_dtype=default_dtype)
#     516   else:
# --> 517     values = ops.convert_to_tensor(
#     518         values,
#     519         name=input_arg.name,
#     520         dtype=dtype,
#     521         as_ref=input_arg.is_ref,
#     522         preferred_dtype=default_dtype)
#     523 except TypeError as err:
#     524   if dtype is None:
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\profiler\trace.py:163, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     161   with Trace(trace_name, **trace_kwargs):
#     162     return func(*args, **kwargs)
# --> 163 return func(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\framework\ops.py:1540, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1535       raise TypeError("convert_to_tensor did not convert to "
#    1536                       "the preferred dtype: %s vs %s " %
#    1537                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1539 if ret is None:
# -> 1540   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1542 if ret is NotImplemented:
#    1543   continue
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1992, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    1991 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 1992   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1393, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1391   return self.read_value().op.inputs[0]
#    1392 else:
# -> 1393   return self.value()
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:565, in BaseResourceVariable.value(self)
#     563   return self._cached_value
#     564 with ops.colocate_with(None, ignore_existing=True):
# --> 565   return self._read_variable_op()
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:672, in BaseResourceVariable._read_variable_op(self)
#     670       result = read_and_set_handle()
#     671 else:
# --> 672   result = read_and_set_handle()
#     674 if not context.executing_eagerly():
#     675   # Note that if a control flow context is active the input of the read op
#     676   # might not actually be the handle. This line bypasses it.
#     677   tape.record_operation(
#     678       "ReadVariableOp", [result], [self._handle],
#     679       backward_function=lambda x: [x],
#     680       forward_function=lambda x: [x])
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:662, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle()
#     661 def read_and_set_handle():
# --> 662   result = gen_resource_variable_ops.read_variable_op(
#     663       self._handle, self._dtype)
#     664   _maybe_set_handle_data(self._dtype, self._handle, result)
#     665   return result
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:483, in read_variable_op(resource, dtype, name)
#     481 # Add nodes to the TensorFlow graph.
#     482 dtype = _execute.make_type(dtype, "dtype")
# --> 483 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     484       "ReadVariableOp", resource=resource, dtype=dtype, name=name)
#     485 _result = _outputs[:]
#     486 if _execute.must_record_gradient():
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\framework\op_def_library.py:748, in _apply_op_helper(op_type_name, name, **keywords)
#     743 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     744                         if arg.is_ref]
#     745 with _MaybeColocateWith(must_colocate_inputs):
#     746   # Add Op to graph
#     747   # pylint: disable=protected-access
# --> 748   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     749                              name=scope, input_types=input_types,
#     750                              attrs=attr_protos, op_def=op_def)
#     752 # `outputs` is returned as a separate return value so that the output
#     753 # tensors can the `op` per se can be decoupled so that the
#     754 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     755 # for more details.
#     756 outputs = op.outputs
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\framework\func_graph.py:590, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     588   inp = self.capture(inp)
#     589   captured_inputs.append(inp)
# --> 590 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     591     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     592     compute_device)
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\framework\ops.py:3528, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3525 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3526 # Session.run call cannot occur between creating and mutating the op.
#    3527 with self._mutation_lock():
# -> 3528   ret = Operation(
#    3529       node_def,
#    3530       self,
#    3531       inputs=inputs,
#    3532       output_types=dtypes,
#    3533       control_inputs=control_inputs,
#    3534       input_types=input_types,
#    3535       original_op=self._default_original_op,
#    3536       op_def=op_def)
#    3537   self._create_op_helper(ret, compute_device=compute_device)
#    3538 return ret
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\framework\ops.py:2015, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2013   if op_def is None:
#    2014     op_def = self._graph._get_op_def(node_def.op)
# -> 2015   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2016                             control_input_ops, op_def)
#    2017   name = compat.as_str(node_def.name)
#    2018 # pylint: enable=protected-access
#
# File c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\tensorflow\python\framework\ops.py:1826, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1824 inputs = _reconstruct_sequence_inputs(op_def, inputs, node_def.attr)
#    1825 # pylint: disable=protected-access
# -> 1826 op_desc = pywrap_tf_session.TF_NewOperation(graph._c_graph,
#    1827                                             compat.as_str(node_def.op),
#    1828                                             compat.as_str(node_def.name))
#    1829 if node_def.device:
#    1830   pywrap_tf_session.TF_SetDevice(op_desc, compat.as_str(node_def.device))
#
# KeyboardInterrupt:

# %%
#define directory where images and masks are located on local disk
image_directory = 'D:/UniBas/Bachelorarbeit/Img_masks/DeepACSA_images_RF/insert_images'
mask_directory = 'D:/UniBas/Bachelorarbeit/Img_masks/DeepACSA_images_RF/insert_masks/'

#define the properties and empty list for resized images and masks
SIZE = 256
image_dataset = []
mask_dataset = []

#define custom function
def IoU(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
    iou = (intersection + smooth) / ( union + smooth)
    return iou

#enumerate and resize images/masks
images = os.listdir(image_directory)
for i, image_name in enumerate(images):    #enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'tif'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory+image_name, 1)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        image_dataset.append(np.array(image))

masks = os.listdir(mask_directory)
for i, image_name in enumerate(masks):
    if (image_name.split('.')[1] == 'tif'):
        image = cv2.imread(mask_directory+image_name, 0)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        mask_dataset.append(np.array(image))

#define some hyperparameters
num_labels = 1  #Binary classificaion (missmatch on coding examples! 1 or 2 for binary classification)
batch_size = 2  #keep it smaller than 3
epochs = 60
num_folds = 5   #define the number of folds (usually 5-10 folds)

#Normalize images
image_dataset = np.array(image_dataset)/255.
#do not normalize masks, just rescale to 0 to 1.
mask_dataset = np.expand_dims((np.array(mask_dataset)),3) /255.

#define the K-fold Cross Validator
kfold = KFold(n_splits=num_folds, shuffle=False)

#define per-fold score containers 
acc_per_fold = []
loss_per_fold = []
IoU_per_fold = []

#K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(image_dataset, mask_dataset):
  callbacks = [
    EarlyStopping(patience=8, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, verbose=1),
    ModelCheckpoint(f'K-foldno{fold_no}-transunet-V1-VL-256.h5', verbose=1, save_best_only=True, save_weights_only=False), # Give the model a name (the .h5 part)
    CSVLogger(f'K-foldno{fold_no}-transunet-V1-VL-256.csv', separator=',', append=False)]
  
  #define the model architecture
  model = models.transunet_2d((256, 256, 3), filter_num=[64, 128, 256, 512, 1024], 
                          n_labels=num_labels, stack_num_down=2, stack_num_up=2, 
                          embed_dim=768, num_mlp=3072, num_heads=12, num_transformer=12, 
                          activation='ReLU', mlp_activation='GELU', output_activation='Sigmoid', #output activation from Softmax to Sigmoid
                          batch_norm=True, pool=True, unpool='bilinear', name='transunet')
                          #batchnorm to true, unpool to false

  #compile the model
  model.compile(loss='binary_crossentropy', optimizer=Adam(lr = 1e-3), 
              metrics=['accuracy', IoU])

  #generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')

  #fit model to data
  transunet_history = model.fit(image_dataset[train], mask_dataset[train], 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(image_dataset[test], mask_dataset[test]), 
                    shuffle=False,
                    epochs=epochs,
                    callbacks=callbacks)

  #append evaluation values for every fold to a list
  acc_per_fold.append(model.evaluate(image_dataset[test], mask_dataset[test])[1])
  loss_per_fold.append(model.evaluate(image_dataset[test], mask_dataset[test])[0])
  IoU_per_fold.append(model.evaluate(image_dataset[test], mask_dataset[test])[2])

  #increase fold number
  fold_no += 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]} - IoU: {IoU_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print(f'> IoU: {np.mean(IoU_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# 25/25 [==============================] - 167s 6s/step - loss: 0.5308 - accuracy: 0.7957 - IoU: 0.7609 - val_loss: 29112.0312 - val_accuracy: 0.0870 - val_IoU: 0.5458
#
# Epoch 00001: val_loss improved from inf to 29112.03125, saving model to K-foldno1-transunet-V1-VL-256.h5
# ------------------------------------------------------------------------
# Training for fold 2 ...
# 25/25 [==============================] - 164s 6s/step - loss: 0.4302 - accuracy: 0.8539 - IoU: 0.8031 - val_loss: 22961.9434 - val_accuracy: 0.0870 - val_IoU: 0.5459
#
# Epoch 00001: val_loss improved from inf to 22961.94336, saving model to K-foldno2-transunet-V1-VL-256.h5
# ------------------------------------------------------------------------
# Training for fold 3 ...
# 26/26 [==============================] - 189s 7s/step - loss: 0.4942 - accuracy: 0.8033 - IoU: 0.7731 - val_loss: 18681.1582 - val_accuracy: 0.0851 - val_IoU: 0.5446
#
# Epoch 00001: val_loss improved from inf to 18681.15820, saving model to K-foldno3-transunet-V1-VL-256.h5
# ------------------------------------------------------------------------
# Training for fold 4 ...
# 26/26 [==============================] - 335s 13s/step - loss: 0.3438 - accuracy: 0.8880 - IoU: 0.8261 - val_loss: 2249.7031 - val_accuracy: 0.0960 - val_IoU: 0.5501
#
# Epoch 00001: val_loss improved from inf to 2249.70312, saving model to K-foldno4-transunet-V1-VL-256.h5
# ------------------------------------------------------------------------
# Training for fold 5 ...
# 26/26 [==============================] - 359s 14s/step - loss: 0.3725 - accuracy: 0.8822 - IoU: 0.8127 - val_loss: 2.2262 - val_accuracy: 0.8237 - val_IoU: 0.9105
#
# Epoch 00001: val_loss improved from inf to 2.22620, saving model to K-foldno5-transunet-V1-VL-256.h5
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: nan (+- nan)
# > Loss: nan
# ------------------------------------------------------------------------
# c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\numpy\core\_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# c:\ProgramData\Anaconda3\envs\DeepACSA\lib\site-packages\numpy\core\_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
