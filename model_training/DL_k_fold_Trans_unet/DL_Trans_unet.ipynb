# %%
import os
#import random
#import pandas as pd
import numpy as np
#import glob
#import matplotlib.pyplot as plt
#plt.style.use("ggplot")
#%matplotlib inline

from sklearn.model_selection import KFold, train_test_split
import cv2

from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model

from keras_unet_collection import models #Keras unet collection
#import tensorflow as tf
from PIL import Image
from datetime import datetime

# %% [markdown]
# ## DL Trans Unet without k-fold

# %%
#define directory where images and masks are located on local disk
image_directory = 'D:/UniBas/Bachelorarbeit/Img_masks/DeepACSA_images_RF/insert_images/'
mask_directory = 'D:/UniBas/Bachelorarbeit/Img_masks/DeepACSA_masks_RF/insert_masks/'


#define the properties and empty list for resized images and masks
SIZE = 256
image_dataset = []
mask_dataset = []


#define custom function
def IoU(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
    iou = (intersection + smooth) / ( union + smooth)
    return iou

#enumerate and resize images/masks
images = os.listdir(image_directory)
for i, image_name in enumerate(images):    #enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'tif'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory+image_name, 1)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        image_dataset.append(np.array(image))


masks = os.listdir(mask_directory)
for i, image_name in enumerate(masks):
    if (image_name.split('.')[1] == 'tif'):
        image = cv2.imread(mask_directory+image_name, 0)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        mask_dataset.append(np.array(image))

#define some hyperparameters
num_labels = 1  #Binary classificaion (missmatch with literature/code examples!)
batch_size = 2  #keep it smaller than 3
epochs = 60

#normalize images
image_dataset = np.array(image_dataset)/255.
#do not normalize masks, just rescale to 0 to 1.
mask_dataset = np.expand_dims((np.array(mask_dataset)),3) /255.

#define callback function
callbacks = [
  EarlyStopping(patience=8, verbose=1),
  ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, verbose=1),
  ModelCheckpoint('A_modelTransV1.h5', verbose=1, save_best_only=True, save_weights_only=False), # Give the model a name (the .h5 part)
  CSVLogger('A_modelTransV1.csv', separator=',', append=False)]

#define the model architecture
#model requires depth >= 2
model = models.transunet_2d((256, 256, 3), filter_num=[64, 128, 256, 512, 1024], 
                          n_labels=num_labels, stack_num_down=2, stack_num_up=2, 
                          embed_dim=768, num_mlp=3072, num_heads=12, num_transformer=12, 
                          activation='ReLU', mlp_activation='GELU', output_activation='Sigmoid', #output activation from Softmax to Sigmoid
                          batch_norm=True, pool=True, unpool=False, name='transunet')
                          #batchnorm to true, unpool to false
#compile the model
model.compile(loss='binary_crossentropy', optimizer=Adam(lr = 1e-3), 
            metrics=['accuracy', IoU])

#split dataset into training and validation set
X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size = 0.10, random_state = 0)

#start time meauserment
start2 = datetime.now() 

# Fit data to model
resunet_history = model.fit(X_train, y_train, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test), 
                    shuffle=False,
                    epochs=epochs,
                    callbacks=callbacks)

#stop time measurement and print the execution time
stop2 = datetime.now() 
execution_time = stop2-start2
print("R2-Unet fitting time is: ", execution_time)

# %% [markdown]
# ## Dl Trans with K-fold-cross validation (k = 5)

# %%
#define directory where images and masks are located
image_directory = 'D:/UniBas/Bachelorarbeit/Img_masks/DeepACSA_images_RF/insert_images/'
mask_directory = 'D:/UniBas/Bachelorarbeit/Img_masks/DeepACSA_masks_RF/insert_masks/'

#define the properties and empty list for resized images and masks
SIZE = 256
image_dataset = []
mask_dataset = []

#define custom function
def IoU(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
    iou = (intersection + smooth) / ( union + smooth)
    return iou

#enumerate and resize images/masks
images = os.listdir(image_directory)
for i, image_name in enumerate(images):    #enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'tif'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory+image_name, 1)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        image_dataset.append(np.array(image))

masks = os.listdir(mask_directory)
for i, image_name in enumerate(masks):
    if (image_name.split('.')[1] == 'tif'):
        image = cv2.imread(mask_directory+image_name, 0)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        mask_dataset.append(np.array(image))

#define some hyperparameters
num_labels = 1  #Binary classificaion (missmatch on coding examples! 1 or 2 for binary classification)
batch_size = 2  #keep it smaller than 3
epochs = 60
num_folds = 5   #define the number of folds (usually 5-10 folds)

#Normalize images
image_dataset = np.array(image_dataset)/255.
#do not normalize masks, just rescale to 0 to 1.
mask_dataset = np.expand_dims((np.array(mask_dataset)),3) /255.

#define the K-fold Cross Validator
kfold = KFold(n_splits=num_folds, shuffle=False)

#define per-fold score containers 
acc_per_fold = []
loss_per_fold = []
IoU_per_fold = []

#K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(image_dataset, mask_dataset):
  callbacks = [
    EarlyStopping(patience=8, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, verbose=1),
    ModelCheckpoint(f'B1RF-Kfoldno{fold_no}-transunet.h5', verbose=1, save_best_only=True, save_weights_only=False), # Give the model a name (the .h5 part)
    CSVLogger(f'B1RF-Kfoldno{fold_no}-transunet.csv', separator=',', append=False)]
  
  #define the model architecture
  model = models.transunet_2d((256, 256, 3), filter_num=[64, 128, 256, 512, 1024], 
                          n_labels=num_labels, stack_num_down=2, stack_num_up=2, 
                          embed_dim=768, num_mlp=3072, num_heads=12, num_transformer=12, 
                          activation='ReLU', mlp_activation='GELU', output_activation='Sigmoid', #output activation from Softmax to Sigmoid
                          batch_norm=True, pool=True, unpool=False, name='transunet')
                          #batchnorm to true, unpool to false

  #compile the model
  model.compile(loss='binary_crossentropy', optimizer=Adam(lr = 1e-3), 
              metrics=['accuracy', IoU])

  #generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')

  #fit model to data
  transunet_history = model.fit(image_dataset[train], mask_dataset[train], 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(image_dataset[test], mask_dataset[test]), 
                    shuffle=False,
                    epochs=epochs,
                    callbacks=callbacks)

  #append evaluation values for every fold to a list
  acc_per_fold.append(model.evaluate(image_dataset[test], mask_dataset[test])[1])
  loss_per_fold.append(model.evaluate(image_dataset[test], mask_dataset[test])[0])
  IoU_per_fold.append(model.evaluate(image_dataset[test], mask_dataset[test])[2])

  #increase fold number
  fold_no += 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]} - IoU: {IoU_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print(f'> IoU: {np.mean(IoU_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/60
# 205/205 [==============================] - 2210s 11s/step - loss: 0.2486 - accuracy: 0.9026 - IoU: 0.8732 - val_loss: 25.9392 - val_accuracy: 0.1225 - val_IoU: 0.5623
#
# Epoch 00001: val_loss improved from inf to 25.93921, saving model to B1RF-Kfoldno1-transunet.h5
# Epoch 2/60
# 205/205 [==============================] - 2202s 11s/step - loss: 0.1086 - accuracy: 0.9552 - IoU: 0.9521 - val_loss: 0.2154 - val_accuracy: 0.8941 - val_IoU: 0.8840
#
# Epoch 00002: val_loss improved from 25.93921 to 0.21538, saving model to B1RF-Kfoldno1-transunet.h5
# Epoch 3/60
# 205/205 [==============================] - 2129s 10s/step - loss: 0.1033 - accuracy: 0.9537 - IoU: 0.9583 - val_loss: 0.1498 - val_accuracy: 0.9191 - val_IoU: 0.9445
#
# Epoch 00003: val_loss improved from 0.21538 to 0.14979, saving model to B1RF-Kfoldno1-transunet.h5
# Epoch 4/60
# 205/205 [==============================] - 2114s 10s/step - loss: 0.0804 - accuracy: 0.9641 - IoU: 0.9691 - val_loss: 2.1382 - val_accuracy: 0.7394 - val_IoU: 0.8678
#
# Epoch 00004: val_loss did not improve from 0.14979
# Epoch 5/60
# 205/205 [==============================] - 2147s 10s/step - loss: 0.0671 - accuracy: 0.9691 - IoU: 0.9745 - val_loss: 0.6660 - val_accuracy: 0.8552 - val_IoU: 0.9245
#
# Epoch 00005: val_loss did not improve from 0.14979
# Epoch 6/60
# 205/205 [==============================] - 2163s 11s/step - loss: 0.0565 - accuracy: 0.9744 - IoU: 0.9790 - val_loss: 0.2472 - val_accuracy: 0.9211 - val_IoU: 0.9545
#
# Epoch 00006: val_loss did not improve from 0.14979
# Epoch 7/60
# 205/205 [==============================] - 2200s 11s/step - loss: 0.0527 - accuracy: 0.9756 - IoU: 0.9806 - val_loss: 0.1033 - val_accuracy: 0.9639 - val_IoU: 0.9780
#
# Epoch 00007: val_loss improved from 0.14979 to 0.10330, saving model to B1RF-Kfoldno1-transunet.h5
# Epoch 8/60
# 205/205 [==============================] - 2340s 11s/step - loss: 0.0472 - accuracy: 0.9776 - IoU: 0.9826 - val_loss: 0.4146 - val_accuracy: 0.9131 - val_IoU: 0.9543
#
# Epoch 00008: val_loss did not improve from 0.10330
# Epoch 9/60
# 205/205 [==============================] - 2370s 12s/step - loss: 0.1089 - accuracy: 0.9491 - IoU: 0.9581 - val_loss: 0.2237 - val_accuracy: 0.9041 - val_IoU: 0.9452
#
# Epoch 00009: val_loss did not improve from 0.10330
# Epoch 10/60
# 205/205 [==============================] - 2360s 12s/step - loss: 0.0859 - accuracy: 0.9599 - IoU: 0.9673 - val_loss: 0.1030 - val_accuracy: 0.9524 - val_IoU: 0.9595
#
# Epoch 00010: val_loss improved from 0.10330 to 0.10298, saving model to B1RF-Kfoldno1-transunet.h5
# Epoch 11/60
# 205/205 [==============================] - 2282s 11s/step - loss: 0.0785 - accuracy: 0.9625 - IoU: 0.9701 - val_loss: 0.1191 - val_accuracy: 0.9432 - val_IoU: 0.9447
#
# Epoch 00011: val_loss did not improve from 0.10298
# Epoch 12/60
# 205/205 [==============================] - 2155s 11s/step - loss: 0.0863 - accuracy: 0.9598 - IoU: 0.9672 - val_loss: 0.1063 - val_accuracy: 0.9473 - val_IoU: 0.9627
#
# Epoch 00012: val_loss did not improve from 0.10298
# Epoch 13/60
# 205/205 [==============================] - 2164s 11s/step - loss: 0.0788 - accuracy: 0.9629 - IoU: 0.9695 - val_loss: 0.1211 - val_accuracy: 0.9404 - val_IoU: 0.9619
#
# Epoch 00013: val_loss did not improve from 0.10298
# Epoch 14/60
# 205/205 [==============================] - 2168s 11s/step - loss: 0.0723 - accuracy: 0.9658 - IoU: 0.9724 - val_loss: 0.6287 - val_accuracy: 0.9131 - val_IoU: 0.9571
#
# Epoch 00014: val_loss did not improve from 0.10298
# Epoch 15/60
# 205/205 [==============================] - 2174s 11s/step - loss: 0.0742 - accuracy: 0.9653 - IoU: 0.9718 - val_loss: 0.0916 - val_accuracy: 0.9526 - val_IoU: 0.9680
#
# Epoch 00015: val_loss improved from 0.10298 to 0.09161, saving model to B1RF-Kfoldno1-transunet.h5
# Epoch 16/60
# 205/205 [==============================] - 2152s 10s/step - loss: 0.0620 - accuracy: 0.9710 - IoU: 0.9764 - val_loss: 0.0984 - val_accuracy: 0.9505 - val_IoU: 0.9593
#
# Epoch 00016: val_loss did not improve from 0.09161
# Epoch 17/60
# 205/205 [==============================] - 2159s 11s/step - loss: 0.0636 - accuracy: 0.9700 - IoU: 0.9758 - val_loss: 0.0731 - val_accuracy: 0.9631 - val_IoU: 0.9727
#
# Epoch 00017: val_loss improved from 0.09161 to 0.07315, saving model to B1RF-Kfoldno1-transunet.h5
# Epoch 18/60
# 205/205 [==============================] - 2158s 11s/step - loss: 0.0586 - accuracy: 0.9724 - IoU: 0.9780 - val_loss: 0.0704 - val_accuracy: 0.9652 - val_IoU: 0.9737
#
# Epoch 00018: val_loss improved from 0.07315 to 0.07041, saving model to B1RF-Kfoldno1-transunet.h5
# Epoch 19/60
# 205/205 [==============================] - 2154s 11s/step - loss: 0.0588 - accuracy: 0.9721 - IoU: 0.9775 - val_loss: 0.1130 - val_accuracy: 0.9473 - val_IoU: 0.9684
#
# Epoch 00019: val_loss did not improve from 0.07041
# Epoch 20/60
# 205/205 [==============================] - 2163s 11s/step - loss: 0.0572 - accuracy: 0.9730 - IoU: 0.9782 - val_loss: 0.0991 - val_accuracy: 0.9517 - val_IoU: 0.9694
#
# Epoch 00020: val_loss did not improve from 0.07041
# Epoch 21/60
# 205/205 [==============================] - 2163s 11s/step - loss: 0.0496 - accuracy: 0.9767 - IoU: 0.9814 - val_loss: 0.1180 - val_accuracy: 0.9460 - val_IoU: 0.9660
#
# Epoch 00021: val_loss did not improve from 0.07041
# Epoch 22/60
# 205/205 [==============================] - 2162s 11s/step - loss: 0.0523 - accuracy: 0.9754 - IoU: 0.9805 - val_loss: 0.1536 - val_accuracy: 0.9228 - val_IoU: 0.9466
#
# Epoch 00022: val_loss did not improve from 0.07041
# Epoch 23/60
# 205/205 [==============================] - 2158s 11s/step - loss: 0.0510 - accuracy: 0.9760 - IoU: 0.9810 - val_loss: 0.0754 - val_accuracy: 0.9663 - val_IoU: 0.9770
#
# Epoch 00023: val_loss did not improve from 0.07041
# Epoch 24/60
# 205/205 [==============================] - 2161s 11s/step - loss: 0.0467 - accuracy: 0.9781 - IoU: 0.9829 - val_loss: 0.0494 - val_accuracy: 0.9772 - val_IoU: 0.9798
#
# Epoch 00024: val_loss improved from 0.07041 to 0.04943, saving model to B1RF-Kfoldno1-transunet.h5
# Epoch 25/60
# 205/205 [==============================] - 2144s 10s/step - loss: 0.0437 - accuracy: 0.9792 - IoU: 0.9839 - val_loss: 0.0439 - val_accuracy: 0.9797 - val_IoU: 0.9825
#
# Epoch 00025: val_loss improved from 0.04943 to 0.04390, saving model to B1RF-Kfoldno1-transunet.h5
# Epoch 26/60
# 205/205 [==============================] - 2157s 11s/step - loss: 0.0446 - accuracy: 0.9783 - IoU: 0.9839 - val_loss: 0.0581 - val_accuracy: 0.9740 - val_IoU: 0.9761
#
# Epoch 00026: val_loss did not improve from 0.04390
# Epoch 27/60
# 205/205 [==============================] - 2161s 11s/step - loss: 0.0415 - accuracy: 0.9798 - IoU: 0.9851 - val_loss: 0.0737 - val_accuracy: 0.9659 - val_IoU: 0.9777
#
# Epoch 00027: val_loss did not improve from 0.04390
# Epoch 28/60
# 205/205 [==============================] - 2157s 11s/step - loss: 0.0410 - accuracy: 0.9799 - IoU: 0.9852 - val_loss: 0.1069 - val_accuracy: 0.9533 - val_IoU: 0.9744
#
# Epoch 00028: val_loss did not improve from 0.04390
# Epoch 29/60
# 205/205 [==============================] - 2165s 11s/step - loss: 0.0382 - accuracy: 0.9811 - IoU: 0.9862 - val_loss: 0.0644 - val_accuracy: 0.9710 - val_IoU: 0.9816
#
# Epoch 00029: val_loss did not improve from 0.04390
# Epoch 30/60
# 205/205 [==============================] - 2160s 11s/step - loss: 0.0366 - accuracy: 0.9817 - IoU: 0.9868 - val_loss: 0.0416 - val_accuracy: 0.9798 - val_IoU: 0.9858
#
# Epoch 00030: val_loss improved from 0.04390 to 0.04158, saving model to B1RF-Kfoldno1-transunet.h5
# Epoch 31/60
# 205/205 [==============================] - 2155s 11s/step - loss: 0.0361 - accuracy: 0.9819 - IoU: 0.9871 - val_loss: 0.3300 - val_accuracy: 0.9197 - val_IoU: 0.9607
#
# Epoch 00031: val_loss did not improve from 0.04158
# Epoch 32/60
# 205/205 [==============================] - 2148s 10s/step - loss: 0.0666 - accuracy: 0.9692 - IoU: 0.9752 - val_loss: 0.0602 - val_accuracy: 0.9717 - val_IoU: 0.9801
#
# Epoch 00032: val_loss did not improve from 0.04158
# Epoch 33/60
# 205/205 [==============================] - 2138s 10s/step - loss: 0.0465 - accuracy: 0.9779 - IoU: 0.9829 - val_loss: 0.0639 - val_accuracy: 0.9702 - val_IoU: 0.9803
#
# Epoch 00033: val_loss did not improve from 0.04158
# Epoch 34/60
# 205/205 [==============================] - 2142s 10s/step - loss: 0.0420 - accuracy: 0.9796 - IoU: 0.9846 - val_loss: 0.0657 - val_accuracy: 0.9696 - val_IoU: 0.9800
#
# Epoch 00034: val_loss did not improve from 0.04158
# Epoch 35/60
# 205/205 [==============================] - 2135s 10s/step - loss: 0.0474 - accuracy: 0.9772 - IoU: 0.9826 - val_loss: 0.1653 - val_accuracy: 0.9267 - val_IoU: 0.9551
#
# Epoch 00035: val_loss did not improve from 0.04158
# Epoch 36/60
# 205/205 [==============================] - 2135s 10s/step - loss: 0.0460 - accuracy: 0.9781 - IoU: 0.9835 - val_loss: 0.0877 - val_accuracy: 0.9608 - val_IoU: 0.9735
#
# Epoch 00036: val_loss did not improve from 0.04158
# Epoch 37/60
# 205/205 [==============================] - 2146s 10s/step - loss: 0.0586 - accuracy: 0.9734 - IoU: 0.9792 - val_loss: 0.0815 - val_accuracy: 0.9614 - val_IoU: 0.9696
#
# Epoch 00037: val_loss did not improve from 0.04158
# Epoch 38/60
# 205/205 [==============================] - 2162s 11s/step - loss: 0.0523 - accuracy: 0.9755 - IoU: 0.9806 - val_loss: 0.0642 - val_accuracy: 0.9706 - val_IoU: 0.9782
#
# Epoch 00038: val_loss did not improve from 0.04158
# Epoch 00038: early stopping
# 4/4 [==============================] - 128s 29s/step - loss: 0.0642 - accuracy: 0.9706 - IoU: 0.9782
# 4/4 [==============================] - 128s 30s/step - loss: 0.0642 - accuracy: 0.9706 - IoU: 0.9782
# 4/4 [==============================] - 129s 30s/step - loss: 0.0642 - accuracy: 0.9706 - IoU: 0.9782
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/60
# 205/205 [==============================] - 2184s 11s/step - loss: 0.2165 - accuracy: 0.9265 - IoU: 0.8948 - val_loss: 4.7626 - val_accuracy: 0.7194 - val_IoU: 0.8504
#
# Epoch 00001: val_loss improved from inf to 4.76258, saving model to B1RF-Kfoldno2-transunet.h5
# Epoch 2/60
# 205/205 [==============================] - 2179s 11s/step - loss: 0.0792 - accuracy: 0.9683 - IoU: 0.9675 - val_loss: 0.2640 - val_accuracy: 0.8936 - val_IoU: 0.8989
#
# Epoch 00002: val_loss improved from 4.76258 to 0.26404, saving model to B1RF-Kfoldno2-transunet.h5
# Epoch 3/60
# 205/205 [==============================] - 2186s 11s/step - loss: 0.0996 - accuracy: 0.9572 - IoU: 0.9605 - val_loss: 0.8658 - val_accuracy: 0.8561 - val_IoU: 0.9217
#
# Epoch 00003: val_loss did not improve from 0.26404
# Epoch 4/60
# 205/205 [==============================] - 2170s 11s/step - loss: 0.0714 - accuracy: 0.9685 - IoU: 0.9722 - val_loss: 0.0988 - val_accuracy: 0.9636 - val_IoU: 0.9774
#
# Epoch 00004: val_loss improved from 0.26404 to 0.09875, saving model to B1RF-Kfoldno2-transunet.h5
# Epoch 5/60
# 205/205 [==============================] - 2175s 11s/step - loss: 0.0648 - accuracy: 0.9708 - IoU: 0.9752 - val_loss: 0.0676 - val_accuracy: 0.9691 - val_IoU: 0.9768
#
# Epoch 00005: val_loss improved from 0.09875 to 0.06761, saving model to B1RF-Kfoldno2-transunet.h5
# Epoch 6/60
# 205/205 [==============================] - 2192s 11s/step - loss: 0.0575 - accuracy: 0.9739 - IoU: 0.9783 - val_loss: 0.0730 - val_accuracy: 0.9677 - val_IoU: 0.9777
#
# Epoch 00006: val_loss did not improve from 0.06761
# Epoch 7/60
# 205/205 [==============================] - 2184s 11s/step - loss: 0.0522 - accuracy: 0.9759 - IoU: 0.9805 - val_loss: 0.0666 - val_accuracy: 0.9690 - val_IoU: 0.9760
#
# Epoch 00007: val_loss improved from 0.06761 to 0.06659, saving model to B1RF-Kfoldno2-transunet.h5
# Epoch 8/60
# 205/205 [==============================] - 2160s 11s/step - loss: 0.0471 - accuracy: 0.9776 - IoU: 0.9825 - val_loss: 0.2141 - val_accuracy: 0.9119 - val_IoU: 0.9463
#
# Epoch 00008: val_loss did not improve from 0.06659
# Epoch 9/60
# 205/205 [==============================] - 2167s 11s/step - loss: 0.0470 - accuracy: 0.9779 - IoU: 0.9829 - val_loss: 0.0694 - val_accuracy: 0.9661 - val_IoU: 0.9736
#
# Epoch 00009: val_loss did not improve from 0.06659
# Epoch 10/60
# 205/205 [==============================] - 2170s 11s/step - loss: 0.0447 - accuracy: 0.9788 - IoU: 0.9833 - val_loss: 0.0533 - val_accuracy: 0.9741 - val_IoU: 0.9797
#
# Epoch 00010: val_loss improved from 0.06659 to 0.05327, saving model to B1RF-Kfoldno2-transunet.h5
# Epoch 11/60
# 205/205 [==============================] - 2172s 11s/step - loss: 0.0387 - accuracy: 0.9811 - IoU: 0.9862 - val_loss: 0.0367 - val_accuracy: 0.9813 - val_IoU: 0.9862
#
# Epoch 00011: val_loss improved from 0.05327 to 0.03672, saving model to B1RF-Kfoldno2-transunet.h5
# Epoch 12/60
# 205/205 [==============================] - 2187s 11s/step - loss: 0.0334 - accuracy: 0.9832 - IoU: 0.9879 - val_loss: 0.0474 - val_accuracy: 0.9776 - val_IoU: 0.9811
#
# Epoch 00012: val_loss did not improve from 0.03672
# Epoch 13/60
# 205/205 [==============================] - 2247s 11s/step - loss: 0.0304 - accuracy: 0.9842 - IoU: 0.9889 - val_loss: 0.0273 - val_accuracy: 0.9852 - val_IoU: 0.9892
#
# Epoch 00013: val_loss improved from 0.03672 to 0.02734, saving model to B1RF-Kfoldno2-transunet.h5
# Epoch 14/60
# 205/205 [==============================] - 2249s 11s/step - loss: 0.0272 - accuracy: 0.9855 - IoU: 0.9901 - val_loss: 0.0320 - val_accuracy: 0.9833 - val_IoU: 0.9881
#
# Epoch 00014: val_loss did not improve from 0.02734
# Epoch 15/60
# 205/205 [==============================] - 2361s 12s/step - loss: 0.0252 - accuracy: 0.9863 - IoU: 0.9909 - val_loss: 0.0263 - val_accuracy: 0.9861 - val_IoU: 0.9895
#
# Epoch 00015: val_loss improved from 0.02734 to 0.02626, saving model to B1RF-Kfoldno2-transunet.h5
# Epoch 16/60
# 205/205 [==============================] - 2232s 11s/step - loss: 0.0225 - accuracy: 0.9875 - IoU: 0.9918 - val_loss: 0.0296 - val_accuracy: 0.9847 - val_IoU: 0.9890
#
# Epoch 00016: val_loss did not improve from 0.02626
# Epoch 17/60
# 205/205 [==============================] - 2191s 11s/step - loss: 0.0210 - accuracy: 0.9880 - IoU: 0.9924 - val_loss: 0.1495 - val_accuracy: 0.9471 - val_IoU: 0.9656
#
# Epoch 00017: val_loss did not improve from 0.02626
# Epoch 18/60
# 205/205 [==============================] - 2188s 11s/step - loss: 0.0316 - accuracy: 0.9841 - IoU: 0.9890 - val_loss: 0.2275 - val_accuracy: 0.9352 - val_IoU: 0.9629
#
# Epoch 00018: val_loss did not improve from 0.02626
# Epoch 19/60
# 205/205 [==============================] - 2171s 11s/step - loss: 0.0370 - accuracy: 0.9820 - IoU: 0.9868 - val_loss: 0.0366 - val_accuracy: 0.9812 - val_IoU: 0.9881
#
# Epoch 00019: val_loss did not improve from 0.02626
# Epoch 20/60
# 205/205 [==============================] - 2186s 11s/step - loss: 0.0273 - accuracy: 0.9856 - IoU: 0.9902 - val_loss: 0.0316 - val_accuracy: 0.9837 - val_IoU: 0.9890
#
# Epoch 00020: val_loss did not improve from 0.02626
# Epoch 21/60
# 205/205 [==============================] - 2174s 11s/step - loss: 0.0212 - accuracy: 0.9879 - IoU: 0.9922 - val_loss: 0.0411 - val_accuracy: 0.9820 - val_IoU: 0.9888
#
# Epoch 00021: val_loss did not improve from 0.02626
# Epoch 22/60
# 205/205 [==============================] - 2197s 11s/step - loss: 0.0184 - accuracy: 0.9890 - IoU: 0.9934 - val_loss: 0.0392 - val_accuracy: 0.9830 - val_IoU: 0.9899
#
# Epoch 00022: val_loss did not improve from 0.02626
# Epoch 23/60
# 205/205 [==============================] - 2185s 11s/step - loss: 0.0167 - accuracy: 0.9897 - IoU: 0.9940 - val_loss: 0.0272 - val_accuracy: 0.9862 - val_IoU: 0.9914
#
# Epoch 00023: val_loss did not improve from 0.02626
# Epoch 00023: early stopping
# 4/4 [==============================] - 133s 31s/step - loss: 0.0272 - accuracy: 0.9862 - IoU: 0.9914
# 4/4 [==============================] - 134s 31s/step - loss: 0.0272 - accuracy: 0.9862 - IoU: 0.9914
# 4/4 [==============================] - 135s 31s/step - loss: 0.0272 - accuracy: 0.9862 - IoU: 0.9914
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/60
# 205/205 [==============================] - 2207s 11s/step - loss: 0.2210 - accuracy: 0.9131 - IoU: 0.8870 - val_loss: 0.7226 - val_accuracy: 0.8126 - val_IoU: 0.9020
#
# Epoch 00001: val_loss improved from inf to 0.72257, saving model to B1RF-Kfoldno3-transunet.h5
# Epoch 2/60
# 205/205 [==============================] - 2153s 11s/step - loss: 0.0629 - accuracy: 0.9743 - IoU: 0.9738 - val_loss: 0.8141 - val_accuracy: 0.8117 - val_IoU: 0.9024
#
# Epoch 00002: val_loss did not improve from 0.72257
# Epoch 3/60
# 205/205 [==============================] - 2164s 11s/step - loss: 0.0438 - accuracy: 0.9805 - IoU: 0.9828 - val_loss: 0.1787 - val_accuracy: 0.9303 - val_IoU: 0.9561
#
# Epoch 00003: val_loss improved from 0.72257 to 0.17871, saving model to B1RF-Kfoldno3-transunet.h5
# Epoch 4/60
# 205/205 [==============================] - 2167s 11s/step - loss: 0.0352 - accuracy: 0.9836 - IoU: 0.9868 - val_loss: 0.1017 - val_accuracy: 0.9582 - val_IoU: 0.9738
#
# Epoch 00004: val_loss improved from 0.17871 to 0.10173, saving model to B1RF-Kfoldno3-transunet.h5
# Epoch 5/60
# 205/205 [==============================] - 2164s 11s/step - loss: 0.0305 - accuracy: 0.9849 - IoU: 0.9888 - val_loss: 0.4458 - val_accuracy: 0.8438 - val_IoU: 0.9045
#
# Epoch 00005: val_loss did not improve from 0.10173
# Epoch 6/60
# 205/205 [==============================] - 2158s 11s/step - loss: 0.0266 - accuracy: 0.9863 - IoU: 0.9903 - val_loss: 0.1821 - val_accuracy: 0.9564 - val_IoU: 0.9767
#
# Epoch 00006: val_loss did not improve from 0.10173
# Epoch 7/60
# 205/205 [==============================] - 2156s 11s/step - loss: 0.0246 - accuracy: 0.9870 - IoU: 0.9911 - val_loss: 0.1030 - val_accuracy: 0.9648 - val_IoU: 0.9780
#
# Epoch 00007: val_loss did not improve from 0.10173
# Epoch 8/60
# 205/205 [==============================] - 2164s 11s/step - loss: 0.0200 - accuracy: 0.9887 - IoU: 0.9926 - val_loss: 0.0451 - val_accuracy: 0.9808 - val_IoU: 0.9875
#
# Epoch 00008: val_loss improved from 0.10173 to 0.04512, saving model to B1RF-Kfoldno3-transunet.h5
# Epoch 9/60
# 205/205 [==============================] - 2164s 11s/step - loss: 0.0172 - accuracy: 0.9897 - IoU: 0.9937 - val_loss: 0.1379 - val_accuracy: 0.9679 - val_IoU: 0.9794
#
# Epoch 00009: val_loss did not improve from 0.04512
# Epoch 10/60
# 205/205 [==============================] - 2158s 11s/step - loss: 0.0153 - accuracy: 0.9904 - IoU: 0.9945 - val_loss: 0.0814 - val_accuracy: 0.9730 - val_IoU: 0.9842
#
# Epoch 00010: val_loss did not improve from 0.04512
# Epoch 11/60
# 205/205 [==============================] - 2156s 11s/step - loss: 0.0132 - accuracy: 0.9912 - IoU: 0.9952 - val_loss: 0.4801 - val_accuracy: 0.9221 - val_IoU: 0.9581
#
# Epoch 00011: val_loss did not improve from 0.04512
# Epoch 12/60
# 205/205 [==============================] - 2210s 11s/step - loss: 0.0185 - accuracy: 0.9893 - IoU: 0.9935 - val_loss: 0.0847 - val_accuracy: 0.9780 - val_IoU: 0.9891
#
# Epoch 00012: val_loss did not improve from 0.04512
# Epoch 13/60
# 205/205 [==============================] - 2249s 11s/step - loss: 0.0153 - accuracy: 0.9905 - IoU: 0.9944 - val_loss: 0.0627 - val_accuracy: 0.9774 - val_IoU: 0.9865
#
# Epoch 00013: val_loss did not improve from 0.04512
# Epoch 14/60
# 205/205 [==============================] - 2168s 11s/step - loss: 0.0124 - accuracy: 0.9914 - IoU: 0.9955 - val_loss: 0.0964 - val_accuracy: 0.9648 - val_IoU: 0.9763
#
# Epoch 00014: val_loss did not improve from 0.04512
# Epoch 15/60
# 205/205 [==============================] - 2171s 11s/step - loss: 0.0128 - accuracy: 0.9913 - IoU: 0.9953 - val_loss: 0.0287 - val_accuracy: 0.9859 - val_IoU: 0.9915
#
# Epoch 00015: val_loss improved from 0.04512 to 0.02868, saving model to B1RF-Kfoldno3-transunet.h5
# Epoch 16/60
# 205/205 [==============================] - 2164s 11s/step - loss: 0.0116 - accuracy: 0.9916 - IoU: 0.9958 - val_loss: 0.0361 - val_accuracy: 0.9839 - val_IoU: 0.9909
#
# Epoch 00016: val_loss did not improve from 0.02868
# Epoch 17/60
# 205/205 [==============================] - 2169s 11s/step - loss: 0.0102 - accuracy: 0.9921 - IoU: 0.9962 - val_loss: 0.0337 - val_accuracy: 0.9848 - val_IoU: 0.9910
#
# Epoch 00017: val_loss did not improve from 0.02868
# Epoch 18/60
# 205/205 [==============================] - 2231s 11s/step - loss: 0.0106 - accuracy: 0.9920 - IoU: 0.9961 - val_loss: 0.0374 - val_accuracy: 0.9854 - val_IoU: 0.9922
#
# Epoch 00018: val_loss did not improve from 0.02868
# Epoch 19/60
# 205/205 [==============================] - 2242s 11s/step - loss: 0.0110 - accuracy: 0.9918 - IoU: 0.9960 - val_loss: 3.6040 - val_accuracy: 0.8165 - val_IoU: 0.9064
#
# Epoch 00019: val_loss did not improve from 0.02868
# Epoch 20/60
# 205/205 [==============================] - 2236s 11s/step - loss: 0.0151 - accuracy: 0.9904 - IoU: 0.9947 - val_loss: 0.0414 - val_accuracy: 0.9835 - val_IoU: 0.9831
#
# Epoch 00020: val_loss did not improve from 0.02868
# Epoch 21/60
# 205/205 [==============================] - 2224s 11s/step - loss: 0.0107 - accuracy: 0.9920 - IoU: 0.9960 - val_loss: 0.0294 - val_accuracy: 0.9871 - val_IoU: 0.9934
#
# Epoch 00021: val_loss did not improve from 0.02868
# Epoch 22/60
# 205/205 [==============================] - 2235s 11s/step - loss: 0.0096 - accuracy: 0.9923 - IoU: 0.9964 - val_loss: 0.0429 - val_accuracy: 0.9837 - val_IoU: 0.9914
#
# Epoch 00022: val_loss did not improve from 0.02868
# Epoch 23/60
# 205/205 [==============================] - 2241s 11s/step - loss: 0.0094 - accuracy: 0.9924 - IoU: 0.9965 - val_loss: 0.0274 - val_accuracy: 0.9874 - val_IoU: 0.9938
#
# Epoch 00023: val_loss improved from 0.02868 to 0.02741, saving model to B1RF-Kfoldno3-transunet.h5
# Epoch 24/60
# 205/205 [==============================] - 2224s 11s/step - loss: 0.0090 - accuracy: 0.9925 - IoU: 0.9966 - val_loss: 0.1755 - val_accuracy: 0.9504 - val_IoU: 0.9730
#
# Epoch 00024: val_loss did not improve from 0.02741
# Epoch 25/60
# 205/205 [==============================] - 2203s 11s/step - loss: 0.0125 - accuracy: 0.9912 - IoU: 0.9954 - val_loss: 0.0427 - val_accuracy: 0.9849 - val_IoU: 0.9921
#
# Epoch 00025: val_loss did not improve from 0.02741
# Epoch 26/60
# 205/205 [==============================] - 2204s 11s/step - loss: 0.0089 - accuracy: 0.9925 - IoU: 0.9967 - val_loss: 0.0277 - val_accuracy: 0.9882 - val_IoU: 0.9943
#
# Epoch 00026: val_loss did not improve from 0.02741
# Epoch 27/60
# 205/205 [==============================] - 2209s 11s/step - loss: 0.0088 - accuracy: 0.9926 - IoU: 0.9968 - val_loss: 0.0341 - val_accuracy: 0.9875 - val_IoU: 0.9942
#
# Epoch 00027: val_loss did not improve from 0.02741
# Epoch 28/60
# 205/205 [==============================] - 2197s 11s/step - loss: 0.0082 - accuracy: 0.9928 - IoU: 0.9969 - val_loss: 0.0367 - val_accuracy: 0.9881 - val_IoU: 0.9945
#
# Epoch 00028: val_loss did not improve from 0.02741
# Epoch 29/60
# 205/205 [==============================] - 2196s 11s/step - loss: 0.0079 - accuracy: 0.9929 - IoU: 0.9970 - val_loss: 0.0355 - val_accuracy: 0.9872 - val_IoU: 0.9939
#
# Epoch 00029: val_loss did not improve from 0.02741
# Epoch 30/60
# 205/205 [==============================] - 2226s 11s/step - loss: 0.0079 - accuracy: 0.9929 - IoU: 0.9971 - val_loss: 0.0471 - val_accuracy: 0.9863 - val_IoU: 0.9936
#
# Epoch 00030: val_loss did not improve from 0.02741
# Epoch 31/60
# 205/205 [==============================] - 2221s 11s/step - loss: 0.0081 - accuracy: 0.9928 - IoU: 0.9970 - val_loss: 1.7336 - val_accuracy: 0.8044 - val_IoU: 0.8984
#
# Epoch 00031: val_loss did not improve from 0.02741
# Epoch 00031: early stopping
# 4/4 [==============================] - 135s 31s/step - loss: 1.7336 - accuracy: 0.8044 - IoU: 0.8984
# 4/4 [==============================] - 131s 30s/step - loss: 1.7336 - accuracy: 0.8044 - IoU: 0.8984
# 4/4 [==============================] - 131s 30s/step - loss: 1.7336 - accuracy: 0.8044 - IoU: 0.8984
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/60
# 205/205 [==============================] - 2459s 12s/step - loss: 0.2543 - accuracy: 0.9049 - IoU: 0.8683 - val_loss: 0.3411 - val_accuracy: 0.9191 - val_IoU: 0.9510
#
# Epoch 00001: val_loss improved from inf to 0.34108, saving model to B1RF-Kfoldno4-transunet.h5
# Epoch 2/60
# 205/205 [==============================] - 2386s 12s/step - loss: 0.0638 - accuracy: 0.9745 - IoU: 0.9710 - val_loss: 1.3756 - val_accuracy: 0.8357 - val_IoU: 0.9130
#
# Epoch 00002: val_loss did not improve from 0.34108
# Epoch 3/60
# 205/205 [==============================] - 2389s 12s/step - loss: 0.0496 - accuracy: 0.9778 - IoU: 0.9798 - val_loss: 0.1765 - val_accuracy: 0.9387 - val_IoU: 0.9590
#
# Epoch 00003: val_loss improved from 0.34108 to 0.17653, saving model to B1RF-Kfoldno4-transunet.h5
# Epoch 4/60
# 205/205 [==============================] - 2364s 12s/step - loss: 0.0387 - accuracy: 0.9819 - IoU: 0.9850 - val_loss: 0.2604 - val_accuracy: 0.9428 - val_IoU: 0.9682
#
# Epoch 00004: val_loss did not improve from 0.17653
# Epoch 5/60
# 205/205 [==============================] - 2376s 12s/step - loss: 0.0346 - accuracy: 0.9837 - IoU: 0.9869 - val_loss: 0.0913 - val_accuracy: 0.9651 - val_IoU: 0.9776
#
# Epoch 00005: val_loss improved from 0.17653 to 0.09128, saving model to B1RF-Kfoldno4-transunet.h5
# Epoch 6/60
# 205/205 [==============================] - 2259s 11s/step - loss: 0.0375 - accuracy: 0.9822 - IoU: 0.9863 - val_loss: 4.8805 - val_accuracy: 0.3774 - val_IoU: 0.6833
#
# Epoch 00006: val_loss did not improve from 0.09128
# Epoch 7/60
# 205/205 [==============================] - 2271s 11s/step - loss: 0.0454 - accuracy: 0.9787 - IoU: 0.9836 - val_loss: 0.3764 - val_accuracy: 0.8907 - val_IoU: 0.9388
#
# Epoch 00007: val_loss did not improve from 0.09128
# Epoch 8/60
# 205/205 [==============================] - 2271s 11s/step - loss: 0.0361 - accuracy: 0.9825 - IoU: 0.9864 - val_loss: 0.0730 - val_accuracy: 0.9693 - val_IoU: 0.9741
#
# Epoch 00008: val_loss improved from 0.09128 to 0.07301, saving model to B1RF-Kfoldno4-transunet.h5
# Epoch 9/60
# 205/205 [==============================] - 2267s 11s/step - loss: 0.0284 - accuracy: 0.9855 - IoU: 0.9895 - val_loss: 0.0631 - val_accuracy: 0.9749 - val_IoU: 0.9809
#
# Epoch 00009: val_loss improved from 0.07301 to 0.06308, saving model to B1RF-Kfoldno4-transunet.h5
# Epoch 10/60
# 205/205 [==============================] - 2259s 11s/step - loss: 0.0260 - accuracy: 0.9864 - IoU: 0.9905 - val_loss: 0.0726 - val_accuracy: 0.9710 - val_IoU: 0.9813
#
# Epoch 00010: val_loss did not improve from 0.06308
# Epoch 11/60
# 205/205 [==============================] - 2265s 11s/step - loss: 0.0212 - accuracy: 0.9883 - IoU: 0.9922 - val_loss: 0.0486 - val_accuracy: 0.9798 - val_IoU: 0.9834
#
# Epoch 00011: val_loss improved from 0.06308 to 0.04865, saving model to B1RF-Kfoldno4-transunet.h5
# Epoch 12/60
# 205/205 [==============================] - 2271s 11s/step - loss: 0.0200 - accuracy: 0.9887 - IoU: 0.9927 - val_loss: 0.0523 - val_accuracy: 0.9795 - val_IoU: 0.9867
#
# Epoch 00012: val_loss did not improve from 0.04865
# Epoch 13/60
# 205/205 [==============================] - 2275s 11s/step - loss: 0.0176 - accuracy: 0.9896 - IoU: 0.9936 - val_loss: 0.0409 - val_accuracy: 0.9816 - val_IoU: 0.9876
#
# Epoch 00013: val_loss improved from 0.04865 to 0.04089, saving model to B1RF-Kfoldno4-transunet.h5
# Epoch 14/60
# 205/205 [==============================] - 2273s 11s/step - loss: 0.0161 - accuracy: 0.9901 - IoU: 0.9941 - val_loss: 0.0529 - val_accuracy: 0.9801 - val_IoU: 0.9882
#
# Epoch 00014: val_loss did not improve from 0.04089
# Epoch 15/60
# 205/205 [==============================] - 2264s 11s/step - loss: 0.0146 - accuracy: 0.9906 - IoU: 0.9948 - val_loss: 0.0450 - val_accuracy: 0.9827 - val_IoU: 0.9898
#
# Epoch 00015: val_loss did not improve from 0.04089
# Epoch 16/60
# 205/205 [==============================] - 2272s 11s/step - loss: 0.0143 - accuracy: 0.9907 - IoU: 0.9950 - val_loss: 3.2999 - val_accuracy: 0.7311 - val_IoU: 0.8585
#
# Epoch 00016: val_loss did not improve from 0.04089
# Epoch 17/60
# 205/205 [==============================] - 2263s 11s/step - loss: 0.0236 - accuracy: 0.9874 - IoU: 0.9916 - val_loss: 0.3350 - val_accuracy: 0.8306 - val_IoU: 0.8846
#
# Epoch 00017: val_loss did not improve from 0.04089
# Epoch 18/60
# 205/205 [==============================] - 2263s 11s/step - loss: 0.0175 - accuracy: 0.9896 - IoU: 0.9936 - val_loss: 0.0400 - val_accuracy: 0.9844 - val_IoU: 0.9913
#
# Epoch 00018: val_loss improved from 0.04089 to 0.03998, saving model to B1RF-Kfoldno4-transunet.h5
# Epoch 19/60
# 205/205 [==============================] - 2295s 11s/step - loss: 0.0145 - accuracy: 0.9906 - IoU: 0.9947 - val_loss: 0.0417 - val_accuracy: 0.9840 - val_IoU: 0.9912
#
# Epoch 00019: val_loss did not improve from 0.03998
# Epoch 20/60
# 205/205 [==============================] - 2281s 11s/step - loss: 0.0126 - accuracy: 0.9913 - IoU: 0.9955 - val_loss: 0.0461 - val_accuracy: 0.9825 - val_IoU: 0.9910
#
# Epoch 00020: val_loss did not improve from 0.03998
# Epoch 21/60
# 205/205 [==============================] - 2281s 11s/step - loss: 0.0114 - accuracy: 0.9917 - IoU: 0.9959 - val_loss: 0.1311 - val_accuracy: 0.9618 - val_IoU: 0.9774
#
# Epoch 00021: val_loss did not improve from 0.03998
# Epoch 22/60
# 205/205 [==============================] - 2265s 11s/step - loss: 0.0160 - accuracy: 0.9901 - IoU: 0.9942 - val_loss: 0.0409 - val_accuracy: 0.9827 - val_IoU: 0.9893
#
# Epoch 00022: val_loss did not improve from 0.03998
# Epoch 23/60
# 205/205 [==============================] - 2266s 11s/step - loss: 0.0128 - accuracy: 0.9912 - IoU: 0.9954 - val_loss: 0.0342 - val_accuracy: 0.9862 - val_IoU: 0.9924
#
# Epoch 00023: val_loss improved from 0.03998 to 0.03416, saving model to B1RF-Kfoldno4-transunet.h5
# Epoch 24/60
# 205/205 [==============================] - 2265s 11s/step - loss: 0.0113 - accuracy: 0.9916 - IoU: 0.9959 - val_loss: 0.0340 - val_accuracy: 0.9862 - val_IoU: 0.9930
#
# Epoch 00024: val_loss improved from 0.03416 to 0.03397, saving model to B1RF-Kfoldno4-transunet.h5
# Epoch 25/60
# 205/205 [==============================] - 2459s 12s/step - loss: 0.0104 - accuracy: 0.9920 - IoU: 0.9962 - val_loss: 0.0269 - val_accuracy: 0.9877 - val_IoU: 0.9940
#
# Epoch 00025: val_loss improved from 0.03397 to 0.02687, saving model to B1RF-Kfoldno4-transunet.h5
# Epoch 26/60
# 205/205 [==============================] - 2494s 12s/step - loss: 0.0099 - accuracy: 0.9922 - IoU: 0.9964 - val_loss: 0.0395 - val_accuracy: 0.9854 - val_IoU: 0.9920
#
# Epoch 00026: val_loss did not improve from 0.02687
# Epoch 27/60
# 205/205 [==============================] - 2437s 12s/step - loss: 0.0105 - accuracy: 0.9920 - IoU: 0.9962 - val_loss: 0.0726 - val_accuracy: 0.9801 - val_IoU: 0.9900
#
# Epoch 00027: val_loss did not improve from 0.02687
# Epoch 28/60
# 205/205 [==============================] - 2340s 11s/step - loss: 0.0100 - accuracy: 0.9922 - IoU: 0.9964 - val_loss: 0.0385 - val_accuracy: 0.9840 - val_IoU: 0.9912
#
# Epoch 00028: val_loss did not improve from 0.02687
# Epoch 29/60
# 205/205 [==============================] - 2348s 11s/step - loss: 0.0104 - accuracy: 0.9920 - IoU: 0.9963 - val_loss: 0.5707 - val_accuracy: 0.9003 - val_IoU: 0.9441
#
# Epoch 00029: val_loss did not improve from 0.02687
# Epoch 30/60
# 205/205 [==============================] - 2358s 12s/step - loss: 0.0194 - accuracy: 0.9889 - IoU: 0.9934 - val_loss: 0.0786 - val_accuracy: 0.9651 - val_IoU: 0.9749
#
# Epoch 00030: val_loss did not improve from 0.02687
# Epoch 31/60
# 205/205 [==============================] - 2294s 11s/step - loss: 0.0135 - accuracy: 0.9910 - IoU: 0.9951 - val_loss: 0.0318 - val_accuracy: 0.9861 - val_IoU: 0.9917
#
# Epoch 00031: val_loss did not improve from 0.02687
# Epoch 32/60
# 205/205 [==============================] - 2274s 11s/step - loss: 0.0135 - accuracy: 0.9909 - IoU: 0.9952 - val_loss: 62.6941 - val_accuracy: 0.2519 - val_IoU: 0.6265
#
# Epoch 00032: val_loss did not improve from 0.02687
# Epoch 33/60
# 205/205 [==============================] - 2279s 11s/step - loss: 0.0740 - accuracy: 0.9658 - IoU: 0.9728 - val_loss: 0.1192 - val_accuracy: 0.9565 - val_IoU: 0.9729
#
# Epoch 00033: val_loss did not improve from 0.02687
# Epoch 00033: early stopping
# 4/4 [==============================] - 145s 33s/step - loss: 0.1192 - accuracy: 0.9565 - IoU: 0.9729
# 4/4 [==============================] - 142s 33s/step - loss: 0.1192 - accuracy: 0.9565 - IoU: 0.9729
# 4/4 [==============================] - 142s 33s/step - loss: 0.1192 - accuracy: 0.9565 - IoU: 0.9729
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/60
# 205/205 [==============================] - 3458s 17s/step - loss: 0.2125 - accuracy: 0.9284 - IoU: 0.8948 - val_loss: 2.1952 - val_accuracy: 0.9159 - val_IoU: 0.9535
#
# Epoch 00001: val_loss improved from inf to 2.19519, saving model to B1RF-Kfoldno5-transunet.h5
# Epoch 2/60
# 205/205 [==============================] - 3430s 17s/step - loss: 0.0778 - accuracy: 0.9681 - IoU: 0.9659 - val_loss: 0.3084 - val_accuracy: 0.9176 - val_IoU: 0.9510
#
# Epoch 00002: val_loss improved from 2.19519 to 0.30842, saving model to B1RF-Kfoldno5-transunet.h5
# Epoch 3/60
# 205/205 [==============================] - 3428s 17s/step - loss: 0.0641 - accuracy: 0.9720 - IoU: 0.9742 - val_loss: 0.5622 - val_accuracy: 0.8899 - val_IoU: 0.9348
#
# Epoch 00003: val_loss did not improve from 0.30842
# Epoch 4/60
# 205/205 [==============================] - 3440s 17s/step - loss: 0.0531 - accuracy: 0.9756 - IoU: 0.9794 - val_loss: 0.7177 - val_accuracy: 0.8674 - val_IoU: 0.9241
#
# Epoch 00004: val_loss did not improve from 0.30842
# Epoch 5/60
# 205/205 [==============================] - 3423s 17s/step - loss: 0.0517 - accuracy: 0.9760 - IoU: 0.9801 - val_loss: 0.2023 - val_accuracy: 0.9268 - val_IoU: 0.9486
#
# Epoch 00005: val_loss improved from 0.30842 to 0.20228, saving model to B1RF-Kfoldno5-transunet.h5
# Epoch 6/60
# 205/205 [==============================] - 3424s 17s/step - loss: 0.0496 - accuracy: 0.9767 - IoU: 0.9811 - val_loss: 0.1070 - val_accuracy: 0.9505 - val_IoU: 0.9707
#
# Epoch 00006: val_loss improved from 0.20228 to 0.10698, saving model to B1RF-Kfoldno5-transunet.h5
# Epoch 7/60
# 205/205 [==============================] - 3405s 17s/step - loss: 0.0421 - accuracy: 0.9799 - IoU: 0.9845 - val_loss: 0.1132 - val_accuracy: 0.9472 - val_IoU: 0.9635
#
# Epoch 00007: val_loss did not improve from 0.10698
# Epoch 8/60
# 205/205 [==============================] - 3425s 17s/step - loss: 0.0402 - accuracy: 0.9808 - IoU: 0.9854 - val_loss: 0.1537 - val_accuracy: 0.9398 - val_IoU: 0.9673
#
# Epoch 00008: val_loss did not improve from 0.10698
# Epoch 9/60
# 205/205 [==============================] - 3404s 17s/step - loss: 0.0363 - accuracy: 0.9820 - IoU: 0.9867 - val_loss: 0.2652 - val_accuracy: 0.9148 - val_IoU: 0.9492
#
# Epoch 00009: val_loss did not improve from 0.10698
# Epoch 10/60
# 205/205 [==============================] - 3404s 17s/step - loss: 0.0359 - accuracy: 0.9823 - IoU: 0.9872 - val_loss: 0.1435 - val_accuracy: 0.9500 - val_IoU: 0.9715
#
# Epoch 00010: val_loss did not improve from 0.10698
# Epoch 11/60
# 205/205 [==============================] - 3431s 17s/step - loss: 0.0306 - accuracy: 0.9843 - IoU: 0.9888 - val_loss: 0.3241 - val_accuracy: 0.9133 - val_IoU: 0.9527
#
# Epoch 00011: val_loss did not improve from 0.10698
# Epoch 12/60
# 205/205 [==============================] - 3417s 17s/step - loss: 0.0334 - accuracy: 0.9830 - IoU: 0.9881 - val_loss: 0.2375 - val_accuracy: 0.9188 - val_IoU: 0.9534
#
# Epoch 00012: val_loss did not improve from 0.10698
# Epoch 13/60
# 205/205 [==============================] - 3403s 17s/step - loss: 0.0291 - accuracy: 0.9848 - IoU: 0.9896 - val_loss: 0.0580 - val_accuracy: 0.9757 - val_IoU: 0.9844
#
# Epoch 00013: val_loss improved from 0.10698 to 0.05801, saving model to B1RF-Kfoldno5-transunet.h5
# Epoch 14/60
# 205/205 [==============================] - 3426s 17s/step - loss: 0.0222 - accuracy: 0.9877 - IoU: 0.9920 - val_loss: 0.2828 - val_accuracy: 0.9091 - val_IoU: 0.9486
#
# Epoch 00014: val_loss did not improve from 0.05801
# Epoch 15/60
# 205/205 [==============================] - 3440s 17s/step - loss: 0.0193 - accuracy: 0.9888 - IoU: 0.9931 - val_loss: 0.0477 - val_accuracy: 0.9788 - val_IoU: 0.9873
#
# Epoch 00015: val_loss improved from 0.05801 to 0.04773, saving model to B1RF-Kfoldno5-transunet.h5
# Epoch 16/60
# 205/205 [==============================] - 3418s 17s/step - loss: 0.0160 - accuracy: 0.9901 - IoU: 0.9941 - val_loss: 0.0398 - val_accuracy: 0.9815 - val_IoU: 0.9893
#
# Epoch 00016: val_loss improved from 0.04773 to 0.03978, saving model to B1RF-Kfoldno5-transunet.h5
# Epoch 17/60
# 205/205 [==============================] - 3398s 17s/step - loss: 0.0149 - accuracy: 0.9905 - IoU: 0.9946 - val_loss: 0.0801 - val_accuracy: 0.9680 - val_IoU: 0.9823
#
# Epoch 00017: val_loss did not improve from 0.03978
# Epoch 18/60
# 205/205 [==============================] - 3400s 17s/step - loss: 0.0138 - accuracy: 0.9908 - IoU: 0.9950 - val_loss: 0.0415 - val_accuracy: 0.9813 - val_IoU: 0.9891
#
# Epoch 00018: val_loss did not improve from 0.03978
# Epoch 19/60
# 205/205 [==============================] - 3399s 17s/step - loss: 0.0142 - accuracy: 0.9907 - IoU: 0.9949 - val_loss: 0.0790 - val_accuracy: 0.9732 - val_IoU: 0.9840
#
# Epoch 00019: val_loss did not improve from 0.03978
# Epoch 20/60
# 205/205 [==============================] - 3388s 17s/step - loss: 0.0164 - accuracy: 0.9899 - IoU: 0.9942 - val_loss: 0.1239 - val_accuracy: 0.9574 - val_IoU: 0.9670
#
# Epoch 00020: val_loss did not improve from 0.03978
# Epoch 21/60
# 205/205 [==============================] - 3402s 17s/step - loss: 0.0234 - accuracy: 0.9875 - IoU: 0.9912 - val_loss: 0.0474 - val_accuracy: 0.9797 - val_IoU: 0.9880
#
# Epoch 00021: val_loss did not improve from 0.03978
# Epoch 22/60
# 205/205 [==============================] - 3400s 17s/step - loss: 0.0147 - accuracy: 0.9907 - IoU: 0.9945 - val_loss: 0.0365 - val_accuracy: 0.9822 - val_IoU: 0.9877
#
# Epoch 00022: val_loss improved from 0.03978 to 0.03653, saving model to B1RF-Kfoldno5-transunet.h5
# Epoch 23/60
# 205/205 [==============================] - 3465s 17s/step - loss: 0.0123 - accuracy: 0.9914 - IoU: 0.9954 - val_loss: 0.0220 - val_accuracy: 0.9879 - val_IoU: 0.9929
#
# Epoch 00023: val_loss improved from 0.03653 to 0.02197, saving model to B1RF-Kfoldno5-transunet.h5
# Epoch 24/60
# 205/205 [==============================] - 3488s 17s/step - loss: 0.0111 - accuracy: 0.9918 - IoU: 0.9959 - val_loss: 0.0190 - val_accuracy: 0.9890 - val_IoU: 0.9939
#
# Epoch 00024: val_loss improved from 0.02197 to 0.01903, saving model to B1RF-Kfoldno5-transunet.h5
# Epoch 25/60
# 205/205 [==============================] - 3459s 17s/step - loss: 0.0103 - accuracy: 0.9920 - IoU: 0.9962 - val_loss: 0.0860 - val_accuracy: 0.9739 - val_IoU: 0.9844
#
# Epoch 00025: val_loss did not improve from 0.01903
# Epoch 26/60
# 205/205 [==============================] - 3464s 17s/step - loss: 0.0114 - accuracy: 0.9917 - IoU: 0.9958 - val_loss: 0.0168 - val_accuracy: 0.9899 - val_IoU: 0.9946
#
# Epoch 00026: val_loss improved from 0.01903 to 0.01677, saving model to B1RF-Kfoldno5-transunet.h5
# Epoch 27/60
# 205/205 [==============================] - 3459s 17s/step - loss: 0.0095 - accuracy: 0.9923 - IoU: 0.9965 - val_loss: 0.0202 - val_accuracy: 0.9891 - val_IoU: 0.9946
#
# Epoch 00027: val_loss did not improve from 0.01677
# Epoch 28/60
# 205/205 [==============================] - 3450s 17s/step - loss: 0.0093 - accuracy: 0.9924 - IoU: 0.9965 - val_loss: 0.0180 - val_accuracy: 0.9895 - val_IoU: 0.9946
#
# Epoch 00028: val_loss did not improve from 0.01677
# Epoch 29/60
# 205/205 [==============================] - 3458s 17s/step - loss: 0.0091 - accuracy: 0.9924 - IoU: 0.9966 - val_loss: 0.0203 - val_accuracy: 0.9894 - val_IoU: 0.9948
#
# Epoch 00029: val_loss did not improve from 0.01677
# Epoch 30/60
# 205/205 [==============================] - 3467s 17s/step - loss: 0.0113 - accuracy: 0.9917 - IoU: 0.9960 - val_loss: 0.0395 - val_accuracy: 0.9834 - val_IoU: 0.9900
#
# Epoch 00030: val_loss did not improve from 0.01677
# Epoch 31/60
# 205/205 [==============================] - 3444s 17s/step - loss: 0.0119 - accuracy: 0.9915 - IoU: 0.9957 - val_loss: 0.0350 - val_accuracy: 0.9838 - val_IoU: 0.9911
#
# Epoch 00031: val_loss did not improve from 0.01677
# Epoch 32/60
# 205/205 [==============================] - 3454s 17s/step - loss: 0.0135 - accuracy: 0.9909 - IoU: 0.9953 - val_loss: 0.2596 - val_accuracy: 0.9588 - val_IoU: 0.9782
#
# Epoch 00032: val_loss did not improve from 0.01677
# Epoch 33/60
# 205/205 [==============================] - 3471s 17s/step - loss: 0.0170 - accuracy: 0.9897 - IoU: 0.9940 - val_loss: 0.0207 - val_accuracy: 0.9886 - val_IoU: 0.9936
#
# Epoch 00033: val_loss did not improve from 0.01677
# Epoch 34/60
# 205/205 [==============================] - 3463s 17s/step - loss: 0.0116 - accuracy: 0.9916 - IoU: 0.9957 - val_loss: 0.0445 - val_accuracy: 0.9816 - val_IoU: 0.9896
#
# Epoch 00034: val_loss did not improve from 0.01677
# Epoch 00034: early stopping
# 4/4 [==============================] - 253s 57s/step - loss: 0.0445 - accuracy: 0.9816 - IoU: 0.9896
# 4/4 [==============================] - 251s 57s/step - loss: 0.0445 - accuracy: 0.9816 - IoU: 0.9896
# 4/4 [==============================] - 251s 57s/step - loss: 0.0445 - accuracy: 0.9816 - IoU: 0.9896
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.06423785537481308 - Accuracy: 0.9706177711486816 - IoU: 0.9782428741455078%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.027152039110660553 - Accuracy: 0.9862439632415771 - IoU: 0.9913702011108398%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 1.733595609664917 - Accuracy: 0.8044126629829407 - IoU: 0.8984137773513794%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.11918218433856964 - Accuracy: 0.956513524055481 - IoU: 0.9729123711585999%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.04449085146188736 - Accuracy: 0.9816409945487976 - IoU: 0.9895691275596619%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 0.9398857831954956 (+- 0.0685076370664334)
# > Loss: 0.39773170799016955
# > IoU: 0.9661016702651978
# ------------------------------------------------------------------------
